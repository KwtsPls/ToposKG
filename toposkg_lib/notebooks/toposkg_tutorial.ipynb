# %% [markdown]
# # A notebook introduction to **toposkg-lib**

# %% [markdown]
# ### Install library and dependencies
#
# toposkg-lib is provided as a pypi package. We recommend that the user installs our version of rdflib, which includes a workaround to speed-up file parsing.

# %%
# !pip install --index-url https://test.pypi.org/simple/ \
  --extra-index-url https://pypi.org/simple \
  "toposkg[full]==0.1.3.dev4"
# !pip install git+https://github.com/SKefalidis/rdflib-speed@main
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple
# Requirement already satisfied: toposkg==0.1.3.dev4 in /usr/local/lib/python3.11/dist-packages (from toposkg[full]==0.1.3.dev4) (0.1.3.dev4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2025.3.0)
# Requirement already satisfied: pyjedai in /usr/local/lib/python3.11/dist-packages (from toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (0.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2.1.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (13.9.4)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (from toposkg[full]==0.1.3.dev4) (1.86.0)
# Requirement already satisfied: unsloth in /usr/local/lib/python3.11/dist-packages (from toposkg[full]==0.1.3.dev4) (2025.5.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai->toposkg[full]==0.1.3.dev4) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai->toposkg[full]==0.1.3.dev4) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai->toposkg[full]==0.1.3.dev4) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai->toposkg[full]==0.1.3.dev4) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai->toposkg[full]==0.1.3.dev4) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai->toposkg[full]==0.1.3.dev4) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai->toposkg[full]==0.1.3.dev4) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai->toposkg[full]==0.1.3.dev4) (4.14.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2025.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (4.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (3.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (3.5)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (3.9.1)
# Requirement already satisfied: scipy==1.12 in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.12.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (0.13.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (4.51.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (4.1.0)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.11.0)
# Requirement already satisfied: py-stringmatching in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (0.4.6)
# Requirement already satisfied: valentine in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (0.2.1)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (4.1.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2.19.1)
# Requirement already satisfied: unsloth_zoo>=2025.5.8 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (2025.5.8)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (2.7.0)
# Requirement already satisfied: xformers>=0.0.27.post2 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.0.30)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.46.0)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (24.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.9.24)
# Requirement already satisfied: datasets>=3.4.1 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (3.6.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.2.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.45.1)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (1.7.0)
# Requirement already satisfied: trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.15.2)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.15.2)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (3.20.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.33.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.33.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from unsloth->toposkg[full]==0.1.3.dev4) (0.22.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (3.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (0.5.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai->toposkg[full]==0.1.3.dev4) (3.10)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (0.3.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (0.70.15)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai->toposkg[full]==0.1.3.dev4) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai->toposkg[full]==0.1.3.dev4) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->toposkg[full]==0.1.3.dev4) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->unsloth->toposkg[full]==0.1.3.dev4) (1.1.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai->toposkg[full]==0.1.3.dev4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai->toposkg[full]==0.1.3.dev4) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai->toposkg[full]==0.1.3.dev4) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (1.11.1.6)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton>=3.0.0->unsloth->toposkg[full]==0.1.3.dev4) (75.2.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.5.8->unsloth->toposkg[full]==0.1.3.dev4) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.5.8->unsloth->toposkg[full]==0.1.3.dev4) (11.2.1)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.5.8->unsloth->toposkg[full]==0.1.3.dev4) (0.19.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers->unsloth->toposkg[full]==0.1.3.dev4) (8.7.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (7.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (3.2.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.5.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.6.1)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth->toposkg[full]==0.1.3.dev4) (0.16)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth->toposkg[full]==0.1.3.dev4) (1.7.2)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth->toposkg[full]==0.1.3.dev4) (4.4.3)
# Requirement already satisfied: anytree<3.0,>=2.9 in /usr/local/lib/python3.11/dist-packages (from valentine->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2.13.0)
# Requirement already satisfied: chardet<6.0.0,>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from valentine->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (5.2.0)
# Requirement already satisfied: jellyfish<1.1,>=0.9 in /usr/local/lib/python3.11/dist-packages (from valentine->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.0.4)
# Requirement already satisfied: PuLP<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from valentine->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2.9.0)
# Requirement already satisfied: pyemd<2.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from valentine->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.0.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (3.11.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (2.4.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (1.17.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers->unsloth->toposkg[full]==0.1.3.dev4) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.4.0->unsloth->toposkg[full]==0.1.3.dev4) (3.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers->pyjedai->toposkg==0.1.3.dev4->toposkg[full]==0.1.3.dev4) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth->toposkg[full]==0.1.3.dev4) (1.20.1)
# Collecting git+https://github.com/SKefalidis/rdflib-speed@main
#   Cloning https://github.com/SKefalidis/rdflib-speed (to revision main) to /tmp/pip-req-build-8zkg998_
#   Running command git clone --filter=blob:none --quiet https://github.com/SKefalidis/rdflib-speed /tmp/pip-req-build-8zkg998_
#   Resolved https://github.com/SKefalidis/rdflib-speed to commit f83c401fe21c30574b2aad04fd2044cc25d70348
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pyparsing<4,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from rdflib==8.0.0a0) (3.2.3)

# %%
# the latest version of unsloth+trasnformers is buggy (see https://github.com/unslothai/unsloth/issues/2656)
# !pip install unsloth==2025.5.7 unsloth-zoo==2025.5.8
# Out:
# Requirement already satisfied: unsloth==2025.5.7 in /usr/local/lib/python3.11/dist-packages (2025.5.7)
# Requirement already satisfied: unsloth-zoo==2025.5.8 in /usr/local/lib/python3.11/dist-packages (2025.5.8)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (2.7.0)
# Requirement already satisfied: xformers>=0.0.27.post2 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.0.30)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.46.0)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (24.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.9.24)
# Requirement already satisfied: transformers!=4.47.0,==4.51.3 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (4.51.3)
# Requirement already satisfied: datasets>=3.4.1 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (3.6.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (1.7.0)
# Requirement already satisfied: trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.15.2)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.15.2)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (3.20.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.33.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.33.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from unsloth==2025.5.7) (0.22.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo==2025.5.8) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo==2025.5.8) (11.2.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo==2025.5.8) (2024.11.6)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo==2025.5.8) (0.19.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,==4.51.3->unsloth==2025.5.7) (3.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,==4.51.3->unsloth==2025.5.7) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,==4.51.3->unsloth==2025.5.7) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,==4.51.3->unsloth==2025.5.7) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,==4.51.3->unsloth==2025.5.7) (0.5.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1->unsloth==2025.5.7) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1->unsloth==2025.5.7) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1->unsloth==2025.5.7) (2.1.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1->unsloth==2025.5.7) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1->unsloth==2025.5.7) (0.70.15)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth==2025.5.7) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->unsloth==2025.5.7) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->unsloth==2025.5.7) (1.1.3)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth==2025.5.7) (1.11.1.6)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton>=3.0.0->unsloth==2025.5.7) (75.2.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth==2025.5.7) (13.9.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers->unsloth==2025.5.7) (8.7.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth==2025.5.7) (0.16)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth==2025.5.7) (1.7.2)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth==2025.5.7) (4.4.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth==2025.5.7) (3.11.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers!=4.47.0,==4.51.3->unsloth==2025.5.7) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers!=4.47.0,==4.51.3->unsloth==2025.5.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers!=4.47.0,==4.51.3->unsloth==2025.5.7) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers!=4.47.0,==4.51.3->unsloth==2025.5.7) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth==2025.5.7) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth==2025.5.7) (2.19.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth==2025.5.7) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers->unsloth==2025.5.7) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.4.0->unsloth==2025.5.7) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=3.4.1->unsloth==2025.5.7) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=3.4.1->unsloth==2025.5.7) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=3.4.1->unsloth==2025.5.7) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth==2025.5.7) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth==2025.5.7) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth==2025.5.7) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth==2025.5.7) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth==2025.5.7) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth==2025.5.7) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1->unsloth==2025.5.7) (1.20.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth==2025.5.7) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.4.1->unsloth==2025.5.7) (1.17.0)

# %%
# !pip show toposkg
# !pip show unsloth
# Out:
# Name: toposkg
# Version: 0.1.3.dev4
# Summary: A Python interface to the ToposKG knowledge graph generation pipeline.
# Home-page:
# Author:
# Author-email: Sergios-Anestis Kefalidis <skefalidis@di.uoa.gr>, Kostas Plas <kplas@di.uoa.gr>
# License: MIT
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: fsspec, pandas, pyjedai, rich
# Required-by:
# Name: unsloth
# Version: 2025.5.7
# Summary: 2-5X faster LLM finetuning
# Home-page: http://www.unsloth.ai
# Author: Unsloth AI team
# Author-email: info@unsloth.ai
# License:
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: accelerate, bitsandbytes, datasets, diffusers, hf_transfer, huggingface_hub, numpy, packaging, peft, protobuf, psutil, sentencepiece, torch, torchvision, tqdm, transformers, triton, trl, tyro, unsloth_zoo, wheel, xformers
# Required-by:

# %% [markdown]
# ## Basics

# %% [markdown]
# ### Setup and exploring available data sources.

# %%
from toposkg.toposkg_lib_core import KnowledgeGraphBlueprintBuilder, KnowledgeGraphSourcesManager

# Load files from the repository. It is advised to skip the download and only download files when they are needed.
sources_manager = KnowledgeGraphSourcesManager(sources_repositories='https://toposkg.di.uoa.gr',)
# Out:
# Do you want to proceed with downloading the entire knowledge graph sources (100gb+)? Any previously downloaded sources will not be redownloaded. (y/n)n
# Skipping download of sources...
# Loading source information from ~/.toposkg/sources_cache

# %%
# Available data sources can be shown as a list of file paths. When shown as a list we can also filter the results to include specific keywords.
sources_manager.print_available_data_sources(tree=False, filter="Greece")
# Out:
# Available data sources:
# /root/.toposkg/sources_cache/toposkg/GAUL/countries/Greece
# /root/.toposkg/sources_cache/toposkg/GAUL/countries/Greece/Greece_0.nt
# /root/.toposkg/sources_cache/toposkg/GAUL/countries/Greece/Greece_1.nt
# /root/.toposkg/sources_cache/toposkg/GAUL/countries/Greece/Greece_2.nt
# /root/.toposkg/sources_cache/toposkg/GAUL/countries/Greece/Greece_all.nt
# /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece
# /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_0.nt
# /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_1.nt
# /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_2.nt
# /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_3.nt
# /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_4.nt
# /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_5.nt
# /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_6.nt
# /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_all.nt
# /root/.toposkg/sources_cache/toposkg/OSM/forests/Greece
# /root/.toposkg/sources_cache/toposkg/OSM/forests/Greece/greece_forest.nt
# /root/.toposkg/sources_cache/toposkg/OSM/pois/Greece
# /root/.toposkg/sources_cache/toposkg/OSM/pois/Greece/greece_poi.nt
# /root/.toposkg/sources_cache/toposkg/OSM/waterbodies/Greece
# /root/.toposkg/sources_cache/toposkg/OSM/waterbodies/Greece/greece_water.nt

# %%
# Or they can be shown in a tree-view. You can expand the output to view the tree (it's quite large).
sources_manager.print_available_data_sources()
# Out:
# Available data sources:
# /root/.toposkg/sources_cache/
#   toposkg/
#     GAUL/
#       countries/
#         Afghanistan/
#           Afghanistan_0.nt
#           Afghanistan_1.nt
#           Afghanistan_2.nt
#           Afghanistan_all.nt
#         Aland Islands/
#           Aland Islands.nt
#         Albania/
#           Albania_0.nt
#           Albania_1.nt
#           Albania_2.nt
#           Albania_all.nt
#         Algeria/
#           Algeria_0.nt
#           Algeria_1.nt
#           Algeria_2.nt
#           Algeria_all.nt
#         American Samoa/
#           American Samoa.nt
#         Andorra/
#           Andorra_0.nt
#           Andorra_all.nt
#         Angola/
#           Angola_0.nt
#           Angola_1.nt
#           Angola_all.nt
#         Anguilla/
#           Anguilla.nt
#         Antarctica/
#           Antarctica.nt
#         Antigua and Barbuda/
#           Antigua and Barbuda.nt
#         Argentina/
#           Argentina_0.nt
#           Argentina_1.nt
#           Argentina_2.nt
#           Argentina_all.nt
#         Armenia/
#           Armenia_0.nt
#           Armenia_1.nt
#           Armenia_2.nt
#           Armenia_all.nt
#         Aruba/
#           Aruba.nt
#         Australia/
#           Australia_0.nt
#           Australia_1.nt
#           Australia_2.nt
#           Australia_all.nt
#         Austria/
#           Austria_0.nt
#           Austria_1.nt
#           Austria_all.nt
#         Azerbaijan/
#           Azerbaijan_0.nt
#           Azerbaijan_1.nt
#           Azerbaijan_2.nt
#           Azerbaijan_all.nt
#         Bahamas/
#           Bahamas_0.nt
#           Bahamas_1.nt
#           Bahamas_all.nt
#         Bahrain/
#           Bahrain.nt
#         Bangladesh/
#           Bangladesh_0.nt
#           Bangladesh_1.nt
#           Bangladesh_2.nt
#           Bangladesh_all.nt
#         Barbados/
#           Barbados.nt
#         Belarus/
#           Belarus_0.nt
#           Belarus_1.nt
#           Belarus_2.nt
#           Belarus_all.nt
#         Belgium/
#           Belgium_0.nt
#           Belgium_1.nt
#           Belgium_2.nt
#           Belgium_all.nt
#         Belize/
#           Belize_0.nt
#           Belize_1.nt
#           Belize_2.nt
#           Belize_all.nt
#         Benin/
#           Benin_0.nt
#           Benin_1.nt
#           Benin_2.nt
#           Benin_all.nt
#         Bermuda/
#           Bermuda.nt
#         Bhutan/
#           Bhutan_0.nt
#           Bhutan_1.nt
#           Bhutan_2.nt
#           Bhutan_all.nt
#         Bolivia/
#           Bolivia_0.nt
#           Bolivia_1.nt
#           Bolivia_2.nt
#           Bolivia_all.nt
#         Bonaire - Sint Eustatius and Saba/
#           Bonaire - Sint Eustatius and Saba.nt
#         Bosnia and Herzegovina/
#           Bosnia and Herzegovina_0.nt
#           Bosnia and Herzegovina_1.nt
#           Bosnia and Herzegovina_2.nt
#           Bosnia and Herzegovina_all.nt
#         Botswana/
#           Botswana_0.nt
#           Botswana_1.nt
#           Botswana_all.nt
#         Bouvet Island/
#           Bouvet Island.nt
#         Brazil/
#           Brazil_0.nt
#           Brazil_1.nt
#           Brazil_2.nt
#           Brazil_all.nt
#         British Indian Ocean Territory/
#           British Indian Ocean Territory.nt
#         Brunei Darussalam/
#           Brunei Darussalam.nt
#         Bulgaria/
#           Bulgaria_0.nt
#           Bulgaria_1.nt
#           Bulgaria_2.nt
#           Bulgaria_all.nt
#         Burkina Faso/
#           Burkina Faso_0.nt
#           Burkina Faso_1.nt
#           Burkina Faso_2.nt
#           Burkina Faso_all.nt
#         Burundi/
#           Burundi_0.nt
#           Burundi_1.nt
#           Burundi_all.nt
#         Cabo Verde/
#           Cabo Verde_0.nt
#           Cabo Verde_1.nt
#           Cabo Verde_2.nt
#           Cabo Verde_all.nt
#         Cambodia/
#           Cambodia_0.nt
#           Cambodia_1.nt
#           Cambodia_2.nt
#           Cambodia_all.nt
#         Cameroon/
#           Cameroon_0.nt
#           Cameroon_1.nt
#           Cameroon_2.nt
#           Cameroon_all.nt
#         Canada/
#           Canada_0.nt
#           Canada_1.nt
#           Canada_2.nt
#           Canada_all.nt
#         Cayman Islands/
#           Cayman Islands.nt
#         Central African Republic/
#           Central African Republic_0.nt
#           Central African Republic_1.nt
#           Central African Republic_2.nt
#           Central African Republic_all.nt
#         Chad/
#           Chad_0.nt
#           Chad_1.nt
#           Chad_all.nt
#         Chile/
#           Chile_0.nt
#           Chile_1.nt
#           Chile_2.nt
#           Chile_all.nt
#         China/
#           China_0.nt
#           China_2.nt
#           China_all.nt
#         Christmas Island/
#           Christmas Island.nt
#         Cocos (Keeling) Islands/
#           Cocos (Keeling) Islands.nt
#         Colombia/
#           Colombia_0.nt
#           Colombia_1.nt
#           Colombia_2.nt
#           Colombia_all.nt
#         Comoros/
#           Comoros.nt
#         Congo/
#           Congo_0.nt
#           Congo_1.nt
#           Congo_2.nt
#           Congo_all.nt
#         Cook Islands/
#           Cook Islands_0.nt
#           Cook Islands_all.nt
#         Costa Rica/
#           Costa Rica_0.nt
#           Costa Rica_1.nt
#           Costa Rica_2.nt
#           Costa Rica_all.nt
#         Cote d'Ivoire/
#           Cote d'Ivoire_0.nt
#           Cote d'Ivoire_1.nt
#           Cote d'Ivoire_2.nt
#           Cote d'Ivoire_all.nt
#         Croatia/
#           Croatia_0.nt
#           Croatia_1.nt
#           Croatia_all.nt
#         Cuba/
#           Cuba_0.nt
#           Cuba_1.nt
#           Cuba_2.nt
#           Cuba_all.nt
#         Curacao/
#           Curacao.nt
#         Cyprus/
#           Cyprus_0.nt
#           Cyprus_1.nt
#           Cyprus_all.nt
#         Czech Republic/
#           Czech Republic_0.nt
#           Czech Republic_1.nt
#           Czech Republic_2.nt
#           Czech Republic_all.nt
#           Czech Republic_fixed.nt
#           Czechia.nt
#         Democratic People's Republic of Korea/
#           Democratic People's Republic of Korea_0.nt
#           Democratic People's Republic of Korea_1.nt
#           Democratic People's Republic of Korea_2.nt
#           Democratic People's Republic of Korea_all.nt
#         Democratic Republic of the Congo/
#           Democratic Republic of the Congo_0.nt
#           Democratic Republic of the Congo_1.nt
#           Democratic Republic of the Congo_2.nt
#           Democratic Republic of the Congo_all.nt
#         Denmark/
#           Denmark_0.nt
#           Denmark_1.nt
#           Denmark_2.nt
#           Denmark_all.nt
#         Djibouti/
#           Djibouti_0.nt
#           Djibouti_1.nt
#           Djibouti_all.nt
#         Dominica/
#           Dominica.nt
#         Dominican Republic/
#           Dominican Republic.nt
#         Ecuador/
#           Ecuador_0.nt
#           Ecuador_1.nt
#           Ecuador_2.nt
#           Ecuador_all.nt
#         Egypt/
#           Egypt_0.nt
#           Egypt_1.nt
#           Egypt_2.nt
#           Egypt_all.nt
#         El Salvador/
#           El Salvador_0.nt
#           El Salvador_1.nt
#           El Salvador_2.nt
#           El Salvador_all.nt
#         Equatorial Guinea/
#           Equatorial Guinea_0.nt
#           Equatorial Guinea_1.nt
#           Equatorial Guinea_2.nt
#           Equatorial Guinea_all.nt
#         Eritrea/
#           Eritrea_0.nt
#           Eritrea_1.nt
#           Eritrea_2.nt
#           Eritrea_all.nt
#         Estonia/
#           Estonia_0.nt
#           Estonia_1.nt
#           Estonia_2.nt
#           Estonia_all.nt
#         Eswatini/
#           Eswatini.nt
#         Ethiopia/
#           Ethiopia_0.nt
#           Ethiopia_1.nt
#           Ethiopia_2.nt
#           Ethiopia_all.nt
#         Falkland Islands (Malvinas)/
#           Falkland Islands (Malvinas).nt
#         Faroe Islands/
#           Faroe Islands_0.nt
#           Faroe Islands_all.nt
#           Faroe Islands_fixed.nt
#         Fiji/
#           Fiji_0.nt
#           Fiji_1.nt
#           Fiji_2.nt
#           Fiji_all.nt
#         Finland/
#           Finland_0.nt
#           Finland_1.nt
#           Finland_2.nt
#           Finland_all.nt
#         France/
#           France_0.nt
#           France_1.nt
#           France_2.nt
#           France_all.nt
#         French Guiana/
#           French Guiana.nt
#         French Polynesia/
#           French Polynesia_0.nt
#           French Polynesia_1.nt
#           French Polynesia_all.nt
#         French Southern Territories/
#           French Southern Territories.nt
#         Gabon/
#           Gabon_0.nt
#           Gabon_1.nt
#           Gabon_2.nt
#           Gabon_all.nt
#         Gambia/
#           Gambia.nt
#         Georgia/
#           Georgia_0.nt
#           Georgia_1.nt
#           Georgia_2.nt
#           Georgia_all.nt
#         Germany/
#           Germany_0.nt
#           Germany_1.nt
#           Germany_2.nt
#           Germany_all.nt
#         Ghana/
#           Ghana_0.nt
#           Ghana_1.nt
#           Ghana_2.nt
#           Ghana_all.nt
#         Gibraltar/
#           Gibraltar.nt
#         Greece/
#           Greece_0.nt
#           Greece_1.nt
#           Greece_2.nt
#           Greece_all.nt
#         Greenland/
#           Greenland.nt
#           Greenland_all.nt
#         Grenada/
#           Grenada.nt
#         Guadeloupe/
#           Guadeloupe.nt
#         Guam/
#           Guam.nt
#         Guatemala/
#           Guatemala_0.nt
#           Guatemala_1.nt
#           Guatemala_2.nt
#           Guatemala_all.nt
#         Guernsey Jersey/
#           Guernsey Jersey_0.nt
#           Guernsey Jersey_1.nt
#           Guernsey Jersey_all.nt
#           Guernsey Jersey_fixed.nt
#           Guernsey.nt
#           Jersey.nt
#         Guinea/
#           Guinea_0.nt
#           Guinea_1.nt
#           Guinea_2.nt
#           Guinea_all.nt
#         Guinea-Bissau/
#           Guinea-Bissau_0.nt
#           Guinea-Bissau_1.nt
#           Guinea-Bissau_2.nt
#           Guinea-Bissau_all.nt
#         Guyana/
#           Guyana_0.nt
#           Guyana_1.nt
#           Guyana_2.nt
#           Guyana_all.nt
#         Haiti/
#           Haiti.nt
#         Heard Island and McDonald Islands/
#           Heard Island and McDonald Islands.nt
#         Holy See/
#           Holy See.nt
#         Honduras/
#           Honduras_0.nt
#           Honduras_1.nt
#           Honduras_2.nt
#           Honduras_all.nt
#         Hong Kong/
#           Hong Kong.nt
#         Hungary/
#           Hungary_0.nt
#           Hungary_1.nt
#           Hungary_2.nt
#           Hungary_all.nt
#         Iceland/
#           Iceland_0.nt
#           Iceland_1.nt
#           Iceland_2.nt
#           Iceland_all.nt
#         India/
#           India_0.nt
#           India_1.nt
#           India_2.nt
#           India_all.nt
#         Indonesia/
#           Indonesia_0.nt
#           Indonesia_1.nt
#           Indonesia_2.nt
#           Indonesia_all.nt
#         Iran/
#           Iran_0.nt
#           Iran_1.nt
#           Iran_2.nt
#           Iran_all.nt
#         Iraq/
#           Iraq_0.nt
#           Iraq_1.nt
#           Iraq_2.nt
#           Iraq_all.nt
#         Ireland/
#           Ireland.nt
#         Isle of Man/
#           Isle of Man.nt
#         Israel/
#           Israel.nt
#         Italy/
#           Italy_0.nt
#           Italy_1.nt
#           Italy_2.nt
#           Italy_all.nt
#         Jamaica/
#           Jamaica_0.nt
#           Jamaica_1.nt
#           Jamaica_all.nt
#         Japan/
#           Japan_0.nt
#           Japan_1.nt
#           Japan_2.nt
#           Japan_all.nt
#         Jordan/
#           Jordan_0.nt
#           Jordan_1.nt
#           Jordan_2.nt
#           Jordan_all.nt
#         Kazakhstan/
#           Kazakhstan_0.nt
#           Kazakhstan_1.nt
#           Kazakhstan_2.nt
#           Kazakhstan_all.nt
#         Kenya/
#           Kenya_0.nt
#           Kenya_1.nt
#           Kenya_2.nt
#           Kenya_all.nt
#         Kiribati/
#           Kiribati_0.nt
#           Kiribati_1.nt
#           Kiribati_2.nt
#           Kiribati_all.nt
#         Kosovo/
#           Kosovo_0.nt
#           Kosovo_all.nt
#         Kuwait/
#           Kuwait.nt
#         Kyrgyzstan/
#           Kyrgyzstan_0.nt
#           Kyrgyzstan_1.nt
#           Kyrgyzstan_2.nt
#           Kyrgyzstan_all.nt
#         Lao People's Democratic Republic/
#           Lao People's Democratic Republic.nt
#         Laos/
#           Lao People's Democratic Republic.nt
#           Laos_0.nt
#           Laos_1.nt
#           Laos_2.nt
#           Laos_all.nt
#           Laos_fixed.nt
#         Latvia/
#           Latvia_0.nt
#           Latvia_1.nt
#           Latvia_2.nt
#           Latvia_all.nt
#         Lebanon/
#           Lebanon_0.nt
#           Lebanon_1.nt
#           Lebanon_2.nt
#           Lebanon_all.nt
#         Lesotho/
#           Lesotho_0.nt
#           Lesotho_1.nt
#           Lesotho_2.nt
#           Lesotho_all.nt
#         Liberia/
#           Liberia_0.nt
#           Liberia_1.nt
#           Liberia_2.nt
#           Liberia_all.nt
#         Libya/
#           Libya_0.nt
#           Libya_1.nt
#           Libya_2.nt
#           Libya_all.nt
#         Liechtenstein/
#           Liechtenstein_0.nt
#           Liechtenstein_1.nt
#           Liechtenstein_all.nt
#         Lithuania/
#           Lithuania_0.nt
#           Lithuania_1.nt
#           Lithuania_2.nt
#           Lithuania_all.nt
#         Luxembourg/
#           Luxembourg_0.nt
#           Luxembourg_1.nt
#           Luxembourg_all.nt
#         Macao/
#           Macao.nt
#         Madagascar/
#           Madagascar_0.nt
#           Madagascar_1.nt
#           Madagascar_2.nt
#           Madagascar_all.nt
#         Malawi/
#           Malawi_0.nt
#           Malawi_1.nt
#           Malawi_2.nt
#           Malawi_all.nt
#         Malaysia/
#           Malaysia.nt
#         Maldives/
#           Maldives_0.nt
#           Maldives_1.nt
#           Maldives_all.nt
#         Mali/
#           Mali_0.nt
#           Mali_1.nt
#           Mali_2.nt
#           Mali_all.nt
#         Malta/
#           Malta_0.nt
#           Malta_1.nt
#           Malta_2.nt
#           Malta_all.nt
#         Marshall Islands/
#           Marshall Islands_0.nt
#           Marshall Islands_all.nt
#         Martinique/
#           Martinique.nt
#         Mauritania/
#           Mauritania_0.nt
#           Mauritania_1.nt
#           Mauritania_2.nt
#           Mauritania_all.nt
#         Mauritius/
#           Mauritius_0.nt
#           Mauritius_1.nt
#           Mauritius_all.nt
#         Mayotte/
#           Mayotte.nt
#         Mexico/
#           Mexico_0.nt
#           Mexico_1.nt
#           Mexico_2.nt
#           Mexico_all.nt
#         Micronesia/
#           Micronesia_0.nt
#           Micronesia_1.nt
#           Micronesia_2.nt
#           Micronesia_all.nt
#         Moldova/
#           Moldova_0.nt
#           Moldova_1.nt
#           Moldova_2.nt
#           Moldova_all.nt
#         Monaco/
#           Monaco_0.nt
#           Monaco_all.nt
#           Monaco_fixed.nt
#         Mongolia/
#           Mongolia_0.nt
#           Mongolia_1.nt
#           Mongolia_2.nt
#           Mongolia_all.nt
#         Montenegro/
#           Montenegro_0.nt
#           Montenegro_1.nt
#           Montenegro_all.nt
#         Montserrat/
#           Montserrat.nt
#         Morocco/
#           Morocco_0.nt
#           Morocco_1.nt
#           Morocco_2.nt
#           Morocco_all.nt
#         Mozambique/
#           Mozambique_0.nt
#           Mozambique_1.nt
#           Mozambique_2.nt
#           Mozambique_all.nt
#         Myanmar/
#           Myanmar_0.nt
#           Myanmar_1.nt
#           Myanmar_2.nt
#           Myanmar_all.nt
#         Namibia/
#           Namibia_0.nt
#           Namibia_1.nt
#           Namibia_2.nt
#           Namibia_all.nt
#         Nauru/
#           Nauru_0.nt
#           Nauru_all.nt
#         Nepal/
#           Nepal_0.nt
#           Nepal_1.nt
#           Nepal_2.nt
#           Nepal_all.nt
#         Netherlands/
#           Netherlands_0.nt
#           Netherlands_1.nt
#           Netherlands_2.nt
#           Netherlands_all.nt
#         New Caledonia/
#           New Caledonia_0.nt
#           New Caledonia_all.nt
#         New Zealand/
#           New Zealand_0.nt
#           New Zealand_1.nt
#           New Zealand_2.nt
#           New Zealand_all.nt
#         Nicaragua/
#           Nicaragua_0.nt
#           Nicaragua_1.nt
#           Nicaragua_2.nt
#           Nicaragua_all.nt
#         Niger/
#           Niger_0.nt
#           Niger_1.nt
#           Niger_2.nt
#           Niger_all.nt
#         Nigeria/
#           Nigeria_0.nt
#           Nigeria_1.nt
#           Nigeria_2.nt
#           Nigeria_all.nt
#         Niue/
#           Niue_0.nt
#           Niue_all.nt
#         Norfolk Island/
#           Norfolk Island.nt
#         North Macedonia/
#           North Macedonia_0.nt
#           North Macedonia_1.nt
#           North Macedonia_2.nt
#           North Macedonia_all.nt
#         Northern Mariana Islands/
#           Northern Mariana Islands.nt
#         Norway/
#           Norway_0.nt
#           Norway_1.nt
#           Norway_2.nt
#           Norway_all.nt
#         Oman/
#           Oman.nt
#         Pakistan/
#           Pakistan_0.nt
#           Pakistan_1.nt
#           Pakistan_2.nt
#           Pakistan_all.nt
#         Palau/
#           Palau_0.nt
#           Palau_all.nt
#         Palestine/
#           Palestine.nt
#         Panama/
#           Panama_0.nt
#           Panama_1.nt
#           Panama_2.nt
#           Panama_all.nt
#         Papua New Guinea/
#           Papua New Guinea_0.nt
#           Papua New Guinea_1.nt
#           Papua New Guinea_2.nt
#           Papua New Guinea_all.nt
#         Paraguay/
#           Paraguay_0.nt
#           Paraguay_1.nt
#           Paraguay_2.nt
#           Paraguay_all.nt
#         Peru/
#           Peru_0.nt
#           Peru_1.nt
#           Peru_2.nt
#           Peru_all.nt
#         Philippines/
#           Philippines_0.nt
#           Philippines_1.nt
#           Philippines_2.nt
#           Philippines_all.nt
#         Pitcairn/
#           Pitcairn_0.nt
#           Pitcairn_all.nt
#         Poland/
#           Poland_0.nt
#           Poland_1.nt
#           Poland_2.nt
#           Poland_all.nt
#         Portugal/
#           Portugal_0.nt
#           Portugal_1.nt
#           Portugal_2.nt
#           Portugal_all.nt
#         Puerto Rico/
#           Puerto Rico.nt
#         Qatar/
#           Qatar.nt
#         Republic of Korea/
#           Republic of Korea_0.nt
#           Republic of Korea_1.nt
#           Republic of Korea_all.nt
#         Romania/
#           Romania_0.nt
#           Romania_1.nt
#           Romania_2.nt
#           Romania_all.nt
#         Russian Federation/
#           Russian Federation_0.nt
#           Russian Federation_1.nt
#           Russian Federation_2.nt
#           Russian Federation_all.nt
#         Rwanda/
#           Rwanda_0.nt
#           Rwanda_1.nt
#           Rwanda_2.nt
#           Rwanda_all.nt
#         Réunion/
#           Réunion.nt
#         Saint Barthelemy/
#           Saint Barthelemy.nt
#         Saint Helena - Ascension and Tristan da Cunha/
#           Saint Helena - Ascension and Tristan da Cunha_0.nt
#           Saint Helena - Ascension and Tristan da Cunha_1.nt
#           Saint Helena - Ascension and Tristan da Cunha_2.nt
#           Saint Helena - Ascension and Tristan da Cunha_all.nt
#         Saint Kitts and Nevis/
#           Saint Kitts and Nevis.nt
#         Saint Lucia/
#           Saint Lucia.nt
#         Saint Martin (French part)/
#           Saint Martin (French part).nt
#         Saint Pierre and Miquelon/
#           Saint Pierre and Miquelon.nt
#         Saint Vincent and the Grenadines/
#           Saint Vincent and the Grenadines.nt
#         Samoa/
#           Samoa_0.nt
#           Samoa_1.nt
#           Samoa_2.nt
#           Samoa_all.nt
#         San Marino/
#           San Marino.nt
#         Sao Tome and Principe/
#           Sao Tome and Principe_0.nt
#           Sao Tome and Principe_1.nt
#           Sao Tome and Principe_2.nt
#           Sao Tome and Principe_all.nt
#         Saudi Arabia/
#           Saudi Arabia.nt
#         Senegal/
#           Senegal.nt
#         Serbia/
#           Serbia_0.nt
#           Serbia_1.nt
#           Serbia_2.nt
#           Serbia_all.nt
#         Seychelles/
#           Seychelles_0.nt
#           Seychelles_1.nt
#           Seychelles_all.nt
#         Sierra Leone/
#           Sierra Leone_0.nt
#           Sierra Leone_1.nt
#           Sierra Leone_2.nt
#           Sierra Leone_all.nt
#         Singapore/
#           Singapore.nt
#         Sint Maarten (Dutch part)/
#           Sint Maarten (Dutch part).nt
#         Slovakia/
#           Slovakia_0.nt
#           Slovakia_1.nt
#           Slovakia_2.nt
#           Slovakia_all.nt
#         Slovenia/
#           Slovenia_0.nt
#           Slovenia_1.nt
#           Slovenia_2.nt
#           Slovenia_all.nt
#         Solomon Islands/
#           Solomon Islands_0.nt
#           Solomon Islands_1.nt
#           Solomon Islands_all.nt
#         Somalia/
#           Somalia_0.nt
#           Somalia_1.nt
#           Somalia_2.nt
#           Somalia_all.nt
#         South Africa/
#           South Africa_0.nt
#           South Africa_1.nt
#           South Africa_2.nt
#           South Africa_all.nt
#         South Georgia and the South Sandwich Islands/
#           South Georgia and the South Sandwich Islands.nt
#         South Sudan/
#           South Sudan_0.nt
#           South Sudan_1.nt
#           South Sudan_2.nt
#           South Sudan_all.nt
#         Spain/
#           Spain_0.nt
#           Spain_1.nt
#           Spain_2.nt
#           Spain_all.nt
#         Sri Lanka/
#           Sri Lanka_0.nt
#           Sri Lanka_1.nt
#           Sri Lanka_2.nt
#           Sri Lanka_all.nt
#         Sudan/
#           Sudan_0.nt
#           Sudan_1.nt
#           Sudan_2.nt
#           Sudan_all.nt
#         Suriname/
#           Suriname_0.nt
#           Suriname_1.nt
#           Suriname_2.nt
#           Suriname_all.nt
#         Svalbard and Jan Mayen/
#           Svalbard and Jan Mayen.nt
#         Sweden/
#           Sweden_0.nt
#           Sweden_1.nt
#           Sweden_2.nt
#           Sweden_all.nt
#         Switzerland/
#           Switzerland_0.nt
#           Switzerland_1.nt
#           Switzerland_2.nt
#           Switzerland_all.nt
#         Syrian Arab Republic/
#           Syrian Arab Republic_0.nt
#           Syrian Arab Republic_1.nt
#           Syrian Arab Republic_2.nt
#           Syrian Arab Republic_all.nt
#         Taiwan/
#           Taiwan.nt
#           Taiwan_all.nt
#         Tajikistan/
#           Tajikistan_0.nt
#           Tajikistan_1.nt
#           Tajikistan_2.nt
#           Tajikistan_all.nt
#         Tanzania/
#           Tanzania_0.nt
#           Tanzania_1.nt
#           Tanzania_2.nt
#           Tanzania_all.nt
#         Thailand/
#           Thailand_0.nt
#           Thailand_1.nt
#           Thailand_2.nt
#           Thailand_all.nt
#         Timor-Leste/
#           Timor-Leste_0.nt
#           Timor-Leste_1.nt
#           Timor-Leste_2.nt
#           Timor-Leste_all.nt
#         Togo/
#           Togo_0.nt
#           Togo_1.nt
#           Togo_2.nt
#           Togo_all.nt
#         Tokelau/
#           Tokelau_0.nt
#           Tokelau_all.nt
#         Tonga/
#           Tonga_0.nt
#           Tonga_1.nt
#           Tonga_2.nt
#           Tonga_all.nt
#         Trinidad and Tobago/
#           Trinidad and Tobago.nt
#         Tunisia/
#           Tunisia_0.nt
#           Tunisia_1.nt
#           Tunisia_2.nt
#           Tunisia_all.nt
#         Turkey/
#           Turkey_0.nt
#           Turkey_1.nt
#           Turkey_2.nt
#           Turkey_all.nt
#           Turkey_fixed.nt
#           Türkiye.nt
#         Turkmenistan/
#           Turkmenistan_0.nt
#           Turkmenistan_1.nt
#           Turkmenistan_all.nt
#         Turks and Caicos Islands/
#           Turks and Caicos Islands.nt
#         Tuvalu/
#           Tuvalu_0.nt
#           Tuvalu_1.nt
#           Tuvalu_all.nt
#         Uganda/
#           Uganda_0.nt
#           Uganda_1.nt
#           Uganda_2.nt
#           Uganda_all.nt
#         Ukraine/
#           Ukraine_0.nt
#           Ukraine_1.nt
#           Ukraine_2.nt
#           Ukraine_all.nt
#         United Arab Emirates/
#           United Arab Emirates.nt
#         United Kingdom/
#           United Kingdom_0.nt
#           United Kingdom_1.nt
#           United Kingdom_2.nt
#           United Kingdom_all.nt
#         United States Minor Outlying Islands/
#           United States Minor Outlying Islands.nt
#         United States of America/
#           United States of America_0.nt
#           United States of America_1.nt
#           United States of America_2.nt
#           United States of America_all.nt
#         Uruguay/
#           Uruguay_0.nt
#           Uruguay_1.nt
#           Uruguay_all.nt
#         Uzbekistan/
#           Uzbekistan_0.nt
#           Uzbekistan_1.nt
#           Uzbekistan_2.nt
#           Uzbekistan_all.nt
#         Vanuatu/
#           Vanuatu_0.nt
#           Vanuatu_1.nt
#           Vanuatu_2.nt
#           Vanuatu_all.nt
#         Venezuela/
#           Venezuela_0.nt
#           Venezuela_1.nt
#           Venezuela_2.nt
#           Venezuela_all.nt
#         Viet Nam/
#           Viet Nam_0.nt
#           Viet Nam_1.nt
#           Viet Nam_2.nt
#           Viet Nam_all.nt
#         Virgin Islands (British)/
#           Virgin Islands (British).nt
#         Virgin Islands (U.S.)/
#           Virgin Islands (U.S.).nt
#         Wallis and Futuna/
#           Wallis and Futuna_0.nt
#           Wallis and Futuna_all.nt
#         Western Sahara/
#           Western Sahara.nt
#         Yemen/
#           Yemen_0.nt
#           Yemen_1.nt
#           Yemen_2.nt
#           Yemen_all.nt
#         Zambia/
#           Zambia_0.nt
#           Zambia_1.nt
#           Zambia_2.nt
#           Zambia_all.nt
#         Zimbabwe/
#           Zimbabwe_0.nt
#           Zimbabwe_1.nt
#           Zimbabwe_2.nt
#           Zimbabwe_all.nt
#     GMBA/
#       mountains.nt
#     MarineRegions/
#       seas.nt
#     OSM/
#       countries/
#         Afghanistan/
#           Afghanistan_0.nt
#           Afghanistan_1.nt
#           Afghanistan_2.nt
#           Afghanistan_all.nt
#         Albania/
#           Albania_0.nt
#           Albania_1.nt
#           Albania_2.nt
#           Albania_3.nt
#           Albania_4.nt
#           Albania_all.nt
#         Algeria/
#           Algeria_0.nt
#           Algeria_1.nt
#           Algeria_2.nt
#           Algeria_all.nt
#         Andorra/
#           Andorra_0.nt
#           Andorra_1.nt
#           Andorra_all.nt
#         Angola/
#           Angola_0.nt
#           Angola_1.nt
#           Angola_2.nt
#           Angola_3.nt
#           Angola_all.nt
#         Argentina/
#           Argentina_0.nt
#           Argentina_1.nt
#           Argentina_2.nt
#           Argentina_3.nt
#           Argentina_4.nt
#           Argentina_5.nt
#           Argentina_6.nt
#           Argentina_all.nt
#         Armenia/
#           Armenia_0.nt
#           Armenia_1.nt
#           Armenia_2.nt
#           Armenia_3.nt
#           Armenia_4.nt
#           Armenia_5.nt
#           Armenia_all.nt
#         Australia/
#           Australia_0.nt
#           Australia_1.nt
#           Australia_2.nt
#           Australia_3.nt
#           Australia_4.nt
#           Australia_all.nt
#         Austria/
#           Austria_0.nt
#           Austria_1.nt
#           Austria_2.nt
#           Austria_3.nt
#           Austria_4.nt
#           Austria_5.nt
#           Austria_all.nt
#         Azerbaijan/
#           Azerbaijan_0.nt
#           Azerbaijan_1.nt
#           Azerbaijan_2.nt
#           Azerbaijan_3.nt
#           Azerbaijan_all.nt
#         Bahamas/
#           Bahamas_0.nt
#           Bahamas_1.nt
#           Bahamas_all.nt
#         Bangladesh/
#           Bangladesh_0.nt
#           Bangladesh_1.nt
#           Bangladesh_2.nt
#           Bangladesh_3.nt
#           Bangladesh_4.nt
#           Bangladesh_5.nt
#           Bangladesh_6.nt
#           Bangladesh_all.nt
#         Belarus/
#           Belarus_0.nt
#           Belarus_1.nt
#           Belarus_2.nt
#           Belarus_3.nt
#           Belarus_4.nt
#           Belarus_5.nt
#           Belarus_all.nt
#         Belgium/
#           Belgium_0.nt
#           Belgium_1.nt
#           Belgium_2.nt
#           Belgium_3.nt
#           Belgium_4.nt
#           Belgium_5.nt
#           Belgium_6.nt
#           Belgium_all.nt
#         Belize/
#           Belize_1.nt
#           Belize_all.nt
#         Benin/
#           Benin_0.nt
#           Benin_1.nt
#           Benin_2.nt
#           Benin_3.nt
#           Benin_4.nt
#           Benin_all.nt
#         Bhutan/
#           Bhutan_1.nt
#           Bhutan_2.nt
#           Bhutan_all.nt
#         Bolivia/
#           Bolivia_0.nt
#           Bolivia_1.nt
#           Bolivia_2.nt
#           Bolivia_3.nt
#           Bolivia_4.nt
#           Bolivia_5.nt
#           Bolivia_6.nt
#           Bolivia_7.nt
#           Bolivia_all.nt
#         Bosnia and Herzegovina/
#           Bosnia and Herzegovina_0.nt
#           Bosnia and Herzegovina_1.nt
#           Bosnia and Herzegovina_2.nt
#           Bosnia and Herzegovina_3.nt
#           Bosnia and Herzegovina_4.nt
#           Bosnia and Herzegovina_5.nt
#           Bosnia and Herzegovina_6.nt
#           Bosnia and Herzegovina_all.nt
#         Botswana/
#           Botswana_0.nt
#           Botswana_1.nt
#           Botswana_2.nt
#           Botswana_3.nt
#           Botswana_all.nt
#         Brazil/
#           Brazil_0.nt
#           Brazil_1.nt
#           Brazil_2.nt
#           Brazil_3.nt
#           Brazil_4.nt
#           Brazil_all.nt
#         Bulgaria/
#           Bulgaria_0.nt
#           Bulgaria_1.nt
#           Bulgaria_2.nt
#           Bulgaria_3.nt
#           Bulgaria_5.nt
#           Bulgaria_6.nt
#           Bulgaria_7.nt
#           Bulgaria_all.nt
#         Burkina Faso/
#           Burkina Faso_1.nt
#           Burkina Faso_2.nt
#           Burkina Faso_3.nt
#           Burkina Faso_5.nt
#           Burkina Faso_6.nt
#           Burkina Faso_all.nt
#         Burundi/
#           Burundi_0.nt
#           Burundi_1.nt
#           Burundi_2.nt
#           Burundi_3.nt
#           Burundi_all.nt
#         Cabo Verde/
#           Cabo Verde_0.nt
#           Cabo Verde_2.nt
#           Cabo Verde_all.nt
#         Cambodia/
#           Cambodia_0.nt
#           Cambodia_1.nt
#           Cambodia_2.nt
#           Cambodia_3.nt
#           Cambodia_all.nt
#         Cameroon/
#           Cameroon_0.nt
#           Cameroon_1.nt
#           Cameroon_2.nt
#           Cameroon_3.nt
#           Cameroon_4.nt
#           Cameroon_5.nt
#           Cameroon_all.nt
#         Canada/
#           Canada_0.nt
#           Canada_1.nt
#           Canada_2.nt
#           Canada_3.nt
#           Canada_4.nt
#           Canada_5.nt
#           Canada_6.nt
#           Canada_7.nt
#           Canada_all.nt
#         Central African Republic/
#           Central African Republic_0.nt
#           Central African Republic_2.nt
#           Central African Republic_all.nt
#         Chad/
#           Chad_0.nt
#           Chad_1.nt
#           Chad_2.nt
#           Chad_3.nt
#           Chad_4.nt
#           Chad_all.nt
#         Chile/
#           Chile_0.nt
#           Chile_1.nt
#           Chile_2.nt
#           Chile_3.nt
#           Chile_all.nt
#         China/
#           China_2.nt
#           China_3.nt
#           China_4.nt
#           China_5.nt
#           China_6.nt
#           China_7.nt
#           China_8.nt
#           China_all.nt
#         Colombia/
#           Colombia_0.nt
#           Colombia_1.nt
#           Colombia_2.nt
#           Colombia_3.nt
#           Colombia_4.nt
#           Colombia_all.nt
#         Congo/
#           Congo_0.nt
#           Congo_1.nt
#           Congo_2.nt
#           Congo_3.nt
#           Congo_4.nt
#           Congo_all.nt
#         Cook Islands/
#           Cook Islands_0.nt
#           Cook Islands_1.nt
#           Cook Islands_all.nt
#         Costa Rica/
#           Costa Rica_0.nt
#           Costa Rica_1.nt
#           Costa Rica_2.nt
#           Costa Rica_3.nt
#           Costa Rica_all.nt
#         Cote d'Ivoire/
#           Cote d'Ivoire_0.nt
#           Cote d'Ivoire_1.nt
#           Cote d'Ivoire_2.nt
#           Cote d'Ivoire_3.nt
#           Cote d'Ivoire_4.nt
#           Cote d'Ivoire_5.nt
#           Cote d'Ivoire_6.nt
#           Cote d'Ivoire_all.nt
#         Croatia/
#           Croatia_0.nt
#           Croatia_1.nt
#           Croatia_2.nt
#           Croatia_3.nt
#           Croatia_4.nt
#           Croatia_5.nt
#           Croatia_all.nt
#         Cuba/
#           Cuba_0.nt
#           Cuba_1.nt
#           Cuba_2.nt
#           Cuba_3.nt
#           Cuba_4.nt
#           Cuba_all.nt
#         Cyprus/
#           Cyprus_0.nt
#           Cyprus_2.nt
#           Cyprus_3.nt
#           Cyprus_4.nt
#           Cyprus_5.nt
#           Cyprus_6.nt
#           Cyprus_all.nt
#         Czech Republic/
#           Czech Republic_0.nt
#           Czech Republic_1.nt
#           Czech Republic_2.nt
#           Czech Republic_3.nt
#           Czech Republic_4.nt
#           Czech Republic_all.nt
#         Democratic People's Republic of Korea/
#           Democratic People's Republic of Korea_0.nt
#           Democratic People's Republic of Korea_1.nt
#           Democratic People's Republic of Korea_2.nt
#           Democratic People's Republic of Korea_3.nt
#           Democratic People's Republic of Korea_4.nt
#           Democratic People's Republic of Korea_all.nt
#         Democratic Republic of the Congo/
#           Democratic Republic of the Congo_0.nt
#           Democratic Republic of the Congo_1.nt
#           Democratic Republic of the Congo_2.nt
#           Democratic Republic of the Congo_3.nt
#           Democratic Republic of the Congo_all.nt
#         Denmark/
#           Denmark_0.nt
#           Denmark_1.nt
#           Denmark_2.nt
#           Denmark_3.nt
#           Denmark_all.nt
#         Djibouti/
#           Djibouti_0.nt
#           Djibouti_1.nt
#           Djibouti_all.nt
#         Ecuador/
#           Ecuador_0.nt
#           Ecuador_1.nt
#           Ecuador_2.nt
#           Ecuador_3.nt
#           Ecuador_all.nt
#         Egypt/
#           Egypt_0.nt
#           Egypt_1.nt
#           Egypt_all.nt
#         El Salvador/
#           El Salvador_0.nt
#           El Salvador_1.nt
#           El Salvador_2.nt
#           El Salvador_3.nt
#           El Salvador_4.nt
#           El Salvador_5.nt
#           El Salvador_6.nt
#           El Salvador_all.nt
#         Equatorial Guinea/
#           Equatorial Guinea_0.nt
#           Equatorial Guinea_1.nt
#           Equatorial Guinea_2.nt
#           Equatorial Guinea_all.nt
#         Eritrea/
#           Eritrea_0.nt
#           Eritrea_1.nt
#           Eritrea_all.nt
#         Estonia/
#           Estonia_0.nt
#           Estonia_1.nt
#           Estonia_2.nt
#           Estonia_3.nt
#           Estonia_4.nt
#           Estonia_5.nt
#           Estonia_all.nt
#         Ethiopia/
#           Ethiopia_1.nt
#           Ethiopia_2.nt
#           Ethiopia_3.nt
#           Ethiopia_4.nt
#           Ethiopia_all.nt
#         Faroe Islands/
#           Faroe Islands_0.nt
#           Faroe Islands_1.nt
#           Faroe Islands_2.nt
#           Faroe Islands_all.nt
#         Fiji/
#           Fiji_0.nt
#           Fiji_1.nt
#           Fiji_2.nt
#           Fiji_all.nt
#         Finland/
#           Finland_0.nt
#           Finland_1.nt
#           Finland_2.nt
#           Finland_3.nt
#           Finland_4.nt
#           Finland_5.nt
#           Finland_all.nt
#         France/
#           France_0.nt
#           France_1.nt
#           France_2.nt
#           France_3.nt
#           France_4.nt
#           France_5.nt
#           France_6.nt
#           France_all.nt
#         French Polynesia/
#           French Polynesia_0.nt
#           French Polynesia_1.nt
#           French Polynesia_all.nt
#         Gabon/
#           Gabon_0.nt
#           Gabon_1.nt
#           Gabon_all.nt
#         Georgia/
#           Georgia_0.nt
#           Georgia_1.nt
#           Georgia_2.nt
#           Georgia_3.nt
#           Georgia_4.nt
#           Georgia_all.nt
#         Germany/
#           Germany_0.nt
#           Germany_1.nt
#           Germany_2.nt
#           Germany_3.nt
#           Germany_4.nt
#           Germany_5.nt
#           Germany_all.nt
#         Ghana/
#           Ghana_0.nt
#           Ghana_1.nt
#           Ghana_2.nt
#           Ghana_3.nt
#           Ghana_all.nt
#         Greece/
#           Greece_0.nt
#           Greece_1.nt
#           Greece_2.nt
#           Greece_3.nt
#           Greece_4.nt
#           Greece_5.nt
#           Greece_6.nt
#           Greece_all.nt
#         Greenland/
#           Greenland_0.nt
#           Greenland_1.nt
#           Greenland_all.nt
#         Guatemala/
#           Guatemala_0.nt
#           Guatemala_1.nt
#           Guatemala_2.nt
#           Guatemala_3.nt
#           Guatemala_all.nt
#         Guernsey Jersey/
#           Guernsey Jersey_0.nt
#           Guernsey Jersey_1.nt
#           Guernsey Jersey_2.nt
#           Guernsey Jersey_3.nt
#           Guernsey Jersey_all.nt
#         Guinea/
#           Guinea_0.nt
#           Guinea_1.nt
#           Guinea_2.nt
#           Guinea_3.nt
#           Guinea_all.nt
#         Guinea-Bissau/
#           Guinea-Bissau_0.nt
#           Guinea-Bissau_1.nt
#           Guinea-Bissau_2.nt
#           Guinea-Bissau_all.nt
#         Guyana/
#           Guyana_0.nt
#           Guyana_1.nt
#           Guyana_all.nt
#         Honduras/
#           Honduras_0.nt
#           Honduras_1.nt
#           Honduras_2.nt
#           Honduras_3.nt
#           Honduras_4.nt
#           Honduras_all.nt
#         Hungary/
#           Hungary_0.nt
#           Hungary_1.nt
#           Hungary_2.nt
#           Hungary_3.nt
#           Hungary_4.nt
#           Hungary_all.nt
#         Iceland/
#           Iceland_0.nt
#           Iceland_1.nt
#           Iceland_2.nt
#           Iceland_3.nt
#           Iceland_4.nt
#           Iceland_all.nt
#         India/
#           India_0.nt
#           India_1.nt
#           India_2.nt
#           India_3.nt
#           India_4.nt
#           India_5.nt
#           India_6.nt
#           India_7.nt
#           India_all.nt
#         Indonesia/
#           Indonesia_0.nt
#           Indonesia_1.nt
#           Indonesia_2.nt
#           Indonesia_3.nt
#           Indonesia_4.nt
#           Indonesia_5.nt
#           Indonesia_6.nt
#           Indonesia_7.nt
#           Indonesia_all.nt
#         Iran/
#           Iran_0.nt
#           Iran_1.nt
#           Iran_2.nt
#           Iran_3.nt
#           Iran_4.nt
#           Iran_5.nt
#           Iran_6.nt
#           Iran_7.nt
#           Iran_all.nt
#         Iraq/
#           Iraq_0.nt
#           Iraq_1.nt
#           Iraq_2.nt
#           Iraq_3.nt
#           Iraq_4.nt
#           Iraq_5.nt
#           Iraq_all.nt
#         Italy/
#           Italy_0.nt
#           Italy_1.nt
#           Italy_2.nt
#           Italy_3.nt
#           Italy_4.nt
#           Italy_5.nt
#           Italy_all.nt
#         Jamaica/
#           Jamaica_0.nt
#           Jamaica_1.nt
#           Jamaica_2.nt
#           Jamaica_3.nt
#           Jamaica_all.nt
#         Japan/
#           Japan_0.nt
#           Japan_1.nt
#           Japan_2.nt
#           Japan_3.nt
#           Japan_4.nt
#           Japan_5.nt
#           Japan_all.nt
#         Jordan/
#           Jordan_0.nt
#           Jordan_1.nt
#           Jordan_2.nt
#           Jordan_3.nt
#           Jordan_all.nt
#         Kazakhstan/
#           Kazakhstan_0.nt
#           Kazakhstan_1.nt
#           Kazakhstan_2.nt
#           Kazakhstan_3.nt
#           Kazakhstan_all.nt
#         Kenya/
#           Kenya_0.nt
#           Kenya_1.nt
#           Kenya_all.nt
#         Kiribati/
#           Kiribati_0.nt
#           Kiribati_2.nt
#           Kiribati_all.nt
#         Kosovo/
#           Kosovo_0.nt
#           Kosovo_2.nt
#           Kosovo_3.nt
#           Kosovo_4.nt
#           Kosovo_all.nt
#         Kyrgyzstan/
#           Kyrgyzstan_0.nt
#           Kyrgyzstan_1.nt
#           Kyrgyzstan_2.nt
#           Kyrgyzstan_3.nt
#           Kyrgyzstan_4.nt
#           Kyrgyzstan_all.nt
#         Laos/
#           Laos_0.nt
#           Laos_1.nt
#           Laos_2.nt
#           Laos_3.nt
#           Laos_all.nt
#         Latvia/
#           Latvia_0.nt
#           Latvia_2.nt
#           Latvia_3.nt
#           Latvia_4.nt
#           Latvia_5.nt
#           Latvia_6.nt
#           Latvia_all.nt
#         Lebanon/
#           Lebanon_0.nt
#           Lebanon_1.nt
#           Lebanon_2.nt
#           Lebanon_4.nt
#           Lebanon_5.nt
#           Lebanon_all.nt
#         Lesotho/
#           Lesotho_0.nt
#           Lesotho_2.nt
#           Lesotho_all.nt
#         Liberia/
#           Liberia_0.nt
#           Liberia_1.nt
#           Liberia_2.nt
#           Liberia_3.nt
#           Liberia_all.nt
#         Libya/
#           Libya_0.nt
#           Libya_2.nt
#           Libya_all.nt
#         Liechtenstein/
#           Liechtenstein_0.nt
#           Liechtenstein_1.nt
#           Liechtenstein_all.nt
#         Lithuania/
#           Lithuania_0.nt
#           Lithuania_1.nt
#           Lithuania_2.nt
#           Lithuania_3.nt
#           Lithuania_4.nt
#           Lithuania_5.nt
#           Lithuania_all.nt
#         Luxembourg/
#           Luxembourg_0.nt
#           Luxembourg_1.nt
#           Luxembourg_2.nt
#           Luxembourg_3.nt
#           Luxembourg_all.nt
#         Madagascar/
#           Madagascar_0.nt
#           Madagascar_1.nt
#           Madagascar_2.nt
#           Madagascar_3.nt
#           Madagascar_4.nt
#           Madagascar_5.nt
#           Madagascar_6.nt
#           Madagascar_all.nt
#         Malawi/
#           Malawi_0.nt
#           Malawi_1.nt
#           Malawi_2.nt
#           Malawi_all.nt
#         Maldives/
#           Maldives_0.nt
#           Maldives_1.nt
#           Maldives_2.nt
#           Maldives_all.nt
#         Mali/
#           Mali_0.nt
#           Mali_1.nt
#           Mali_2.nt
#           Mali_3.nt
#           Mali_all.nt
#         Malta/
#           Malta_0.nt
#           Malta_2.nt
#           Malta_all.nt
#         Marshall Islands/
#           Marshall Islands_0.nt
#           Marshall Islands_1.nt
#           Marshall Islands_2.nt
#           Marshall Islands_all.nt
#         Mauritania/
#           Mauritania_0.nt
#           Mauritania_1.nt
#           Mauritania_all.nt
#         Mauritius/
#           Mauritius_0.nt
#           Mauritius_1.nt
#           Mauritius_3.nt
#           Mauritius_all.nt
#         Mexico/
#           Mexico_0.nt
#           Mexico_1.nt
#           Mexico_2.nt
#           Mexico_3.nt
#           Mexico_4.nt
#           Mexico_all.nt
#         Micronesia/
#           Micronesia_0.nt
#           Micronesia_1.nt
#           Micronesia_2.nt
#           Micronesia_all.nt
#         Moldova/
#           Moldova_0.nt
#           Moldova_1.nt
#           Moldova_2.nt
#           Moldova_3.nt
#           Moldova_4.nt
#           Moldova_5.nt
#           Moldova_6.nt
#           Moldova_7.nt
#           Moldova_8.nt
#           Moldova_all.nt
#         Monaco/
#           Monaco_0.nt
#           Monaco_1.nt
#           Monaco_2.nt
#           Monaco_all.nt
#         Mongolia/
#           Mongolia_0.nt
#           Mongolia_1.nt
#           Mongolia_2.nt
#           Mongolia_3.nt
#           Mongolia_all.nt
#         Montenegro/
#           Montenegro_0.nt
#           Montenegro_1.nt
#           Montenegro_2.nt
#           Montenegro_all.nt
#         Morocco/
#           Morocco_0.nt
#           Morocco_1.nt
#           Morocco_2.nt
#           Morocco_3.nt
#           Morocco_4.nt
#           Morocco_5.nt
#           Morocco_all.nt
#         Mozambique/
#           Mozambique_0.nt
#           Mozambique_1.nt
#           Mozambique_2.nt
#           Mozambique_3.nt
#           Mozambique_4.nt
#           Mozambique_all.nt
#         Myanmar/
#           Myanmar_0.nt
#           Myanmar_1.nt
#           Myanmar_2.nt
#           Myanmar_3.nt
#           Myanmar_4.nt
#           Myanmar_5.nt
#           Myanmar_6.nt
#           Myanmar_7.nt
#           Myanmar_8.nt
#           Myanmar_all.nt
#         Namibia/
#           Namibia_0.nt
#           Namibia_1.nt
#           Namibia_2.nt
#           Namibia_all.nt
#         Nauru/
#           Nauru_0.nt
#           Nauru_1.nt
#           Nauru_2.nt
#           Nauru_all.nt
#         Nepal/
#           Nepal_0.nt
#           Nepal_1.nt
#           Nepal_2.nt
#           Nepal_3.nt
#           Nepal_4.nt
#           Nepal_all.nt
#         Netherlands/
#           Netherlands_0.nt
#           Netherlands_1.nt
#           Netherlands_2.nt
#           Netherlands_3.nt
#           Netherlands_all.nt
#         New Caledonia/
#           New Caledonia_0.nt
#           New Caledonia_1.nt
#           New Caledonia_all.nt
#         New Zealand/
#           New Zealand_0.nt
#           New Zealand_1.nt
#           New Zealand_2.nt
#           New Zealand_3.nt
#           New Zealand_all.nt
#         Nicaragua/
#           Nicaragua_0.nt
#           Nicaragua_1.nt
#           Nicaragua_2.nt
#           Nicaragua_5.nt
#           Nicaragua_all.nt
#         Niger/
#           Niger_0.nt
#           Niger_1.nt
#           Niger_2.nt
#           Niger_3.nt
#           Niger_all.nt
#         Nigeria/
#           Nigeria_1.nt
#           Nigeria_2.nt
#           Nigeria_3.nt
#           Nigeria_all.nt
#         Niue/
#           Niue_0.nt
#           Niue_all.nt
#         North Macedonia/
#           North Macedonia_0.nt
#           North Macedonia_2.nt
#           North Macedonia_3.nt
#           North Macedonia_4.nt
#           North Macedonia_all.nt
#         Norway/
#           Norway_0.nt
#           Norway_1.nt
#           Norway_2.nt
#           Norway_3.nt
#           Norway_all.nt
#         Pakistan/
#           Pakistan_0.nt
#           Pakistan_1.nt
#           Pakistan_2.nt
#           Pakistan_3.nt
#           Pakistan_4.nt
#           Pakistan_5.nt
#           Pakistan_all.nt
#         Palau/
#           Palau_0.nt
#           Palau_1.nt
#           Palau_all.nt
#         Panama/
#           Panama_1.nt
#           Panama_2.nt
#           Panama_3.nt
#           Panama_4.nt
#           Panama_5.nt
#           Panama_all.nt
#         Papua New Guinea/
#           Papua New Guinea_0.nt
#           Papua New Guinea_1.nt
#           Papua New Guinea_all.nt
#         Paraguay/
#           Paraguay_0.nt
#           Paraguay_1.nt
#           Paraguay_2.nt
#           Paraguay_all.nt
#         Peru/
#           Peru_0.nt
#           Peru_1.nt
#           Peru_2.nt
#           Peru_3.nt
#           Peru_4.nt
#           Peru_all.nt
#         Philippines/
#           Philippines_0.nt
#           Philippines_1.nt
#           Philippines_2.nt
#           Philippines_3.nt
#           Philippines_4.nt
#           Philippines_5.nt
#           Philippines_6.nt
#           Philippines_7.nt
#           Philippines_8.nt
#           Philippines_all.nt
#         Pitcairn/
#           Pitcairn_0.nt
#           Pitcairn_all.nt
#         Poland/
#           Poland_0.nt
#           Poland_1.nt
#           Poland_2.nt
#           Poland_3.nt
#           Poland_4.nt
#           Poland_5.nt
#           Poland_6.nt
#           Poland_7.nt
#           Poland_all.nt
#         Portugal/
#           Portugal_0.nt
#           Portugal_1.nt
#           Portugal_2.nt
#           Portugal_3.nt
#           Portugal_4.nt
#           Portugal_all.nt
#         Republic of Korea/
#           Republic of Korea_0.nt
#           Republic of Korea_1.nt
#           Republic of Korea_2.nt
#           Republic of Korea_3.nt
#           Republic of Korea_all.nt
#         Romania/
#           Romania_0.nt
#           Romania_1.nt
#           Romania_2.nt
#           Romania_3.nt
#           Romania_4.nt
#           Romania_5.nt
#           Romania_6.nt
#           Romania_7.nt
#           Romania_all.nt
#         Russian Federation/
#           Russian Federation_0.nt
#           Russian Federation_1.nt
#           Russian Federation_2.nt
#           Russian Federation_3.nt
#           Russian Federation_4.nt
#           Russian Federation_5.nt
#           Russian Federation_6.nt
#           Russian Federation_all.nt
#         Rwanda/
#           Rwanda_0.nt
#           Rwanda_1.nt
#           Rwanda_2.nt
#           Rwanda_4.nt
#           Rwanda_5.nt
#           Rwanda_all.nt
#         Saint Helena - Ascension and Tristan da Cunha/
#           Saint Helena - Ascension and Tristan da Cunha_0.nt
#           Saint Helena - Ascension and Tristan da Cunha_1.nt
#           Saint Helena - Ascension and Tristan da Cunha_all.nt
#         Samoa/
#           Samoa_0.nt
#           Samoa_1.nt
#           Samoa_all.nt
#         Sao Tome and Principe/
#           Sao Tome and Principe_0.nt
#           Sao Tome and Principe_1.nt
#           Sao Tome and Principe_2.nt
#           Sao Tome and Principe_3.nt
#           Sao Tome and Principe_all.nt
#         Serbia/
#           Serbia_0.nt
#           Serbia_1.nt
#           Serbia_2.nt
#           Serbia_3.nt
#           Serbia_4.nt
#           Serbia_all.nt
#         Seychelles/
#           Seychelles_0.nt
#           Seychelles_1.nt
#           Seychelles_2.nt
#           Seychelles_all.nt
#         Sierra Leone/
#           Sierra Leone_0.nt
#           Sierra Leone_1.nt
#           Sierra Leone_2.nt
#           Sierra Leone_3.nt
#           Sierra Leone_4.nt
#           Sierra Leone_all.nt
#         Slovakia/
#           Slovakia_0.nt
#           Slovakia_1.nt
#           Slovakia_2.nt
#           Slovakia_3.nt
#           Slovakia_4.nt
#           Slovakia_all.nt
#         Slovenia/
#           Slovenia_0.nt
#           Slovenia_2.nt
#           Slovenia_3.nt
#           Slovenia_all.nt
#         Solomon Islands/
#           Solomon Islands_0.nt
#           Solomon Islands_1.nt
#           Solomon Islands_2.nt
#           Solomon Islands_all.nt
#         Somalia/
#           Somalia_0.nt
#           Somalia_1.nt
#           Somalia_2.nt
#           Somalia_3.nt
#           Somalia_all.nt
#         South Africa/
#           South Africa_0.nt
#           South Africa_1.nt
#           South Africa_2.nt
#           South Africa_4.nt
#           South Africa_all.nt
#         South Sudan/
#           South Sudan_0.nt
#           South Sudan_1.nt
#           South Sudan_all.nt
#         Spain/
#           Spain_0.nt
#           Spain_1.nt
#           Spain_2.nt
#           Spain_3.nt
#           Spain_4.nt
#           Spain_5.nt
#           Spain_6.nt
#           Spain_all.nt
#         Sri Lanka/
#           Sri Lanka_0.nt
#           Sri Lanka_1.nt
#           Sri Lanka_2.nt
#           Sri Lanka_3.nt
#           Sri Lanka_4.nt
#           Sri Lanka_5.nt
#           Sri Lanka_6.nt
#           Sri Lanka_all.nt
#         Sudan/
#           Sudan_0.nt
#           Sudan_1.nt
#           Sudan_all.nt
#         Suriname/
#           Suriname_1.nt
#           Suriname_all.nt
#         Sweden/
# ...
#         Djibouti/
#           djibouti_poi.nt
#         East Timor/
#           east timor_poi.nt
#         Ecuador/
#           ecuador_poi.nt
#         Egypt/
#           egypt_poi.nt
#         El Salvador/
#           el salvador_poi.nt
#         Equatorial Guinea/
#           equatorial guinea_poi.nt
#         Eritrea/
#           eritrea_poi.nt
#         Estonia/
#           estonia_poi.nt
#         Ethiopia/
#           ethiopia_poi.nt
#         Faroe Islands/
#           faroe islands_poi.nt
#         Fiji/
#           fiji_poi.nt
#         Finland/
#           finland_poi.nt
#         France/
#           france_poi.nt
#         GCC States/
#           gcc states_poi.nt
#         Gabon/
#           gabon_poi.nt
#         Georgia/
#           georgia_poi.nt
#         Germany/
#           germany_poi.nt
#         Ghana/
#           ghana_poi.nt
#         Greece/
#           greece_poi.nt
#         Greenland/
#           greenland_poi.nt
#         Guatemala/
#           guatemala_poi.nt
#         Guernsey Jersey/
#           guernsey jersey_poi.nt
#         Guinea/
#           guinea_poi.nt
#         Guinea-Bissau/
#           guinea-bissau_poi.nt
#         Guyana/
#           guyana_poi.nt
#         Haiti and Dominican Republic/
#           haiti and dominican republic_poi.nt
#         Honduras/
#           honduras_poi.nt
#         Hungary/
#           hungary_poi.nt
#         Iceland/
#           iceland_poi.nt
#         Ile de Clipperton/
#           ile de clipperton_poi.nt
#         India/
#           india_poi.nt
#         Indonesia/
#           indonesia_poi.nt
#         Iran/
#           iran_poi.nt
#         Iraq/
#           iraq_poi.nt
#         Ireland and Northern Ireland/
#           ireland and northern ireland_poi.nt
#         Isle of Man/
#           isle of man_poi.nt
#         Israel and Palestine/
#           israel and palestine_poi.nt
#         Italy/
#           italy_poi.nt
#         Ivory Coast/
#           ivory coast_poi.nt
#         Jamaica/
#           jamaica_poi.nt
#         Japan/
#           japan_poi.nt
#         Jordan/
#           jordan_poi.nt
#         Kazakhstan/
#           kazakhstan_poi.nt
#         Kenya/
#           kenya_poi.nt
#         Kiribati/
#           kiribati_poi.nt
#         Kosovo/
#           kosovo_poi.nt
#         Kyrgyzstan/
#           kyrgyzstan_poi.nt
#         Laos/
#           laos_poi.nt
#         Latvia/
#           latvia_poi.nt
#         Lebanon/
#           lebanon_poi.nt
#         Lesotho/
#           lesotho_poi.nt
#         Liberia/
#           liberia_poi.nt
#         Libya/
#           libya_poi.nt
#         Liechtenstein/
#           liechtenstein_poi.nt
#         Lithuania/
#           lithuania_poi.nt
#         Luxembourg/
#           luxembourg_poi.nt
#         Macedonia/
#           macedonia_poi.nt
#         Madagascar/
#           madagascar_poi.nt
#         Malawi/
#           malawi_poi.nt
#         Malaysia Singapore Brunei/
#           malaysia singapore brunei_poi.nt
#         Maldives/
#           maldives_poi.nt
#         Mali/
#           mali_poi.nt
#         Malta/
#           malta_poi.nt
#         Marshall Islands/
#           marshall islands_poi.nt
#         Mauritania/
#           mauritania_poi.nt
#         Mauritiusp/
#           mauritiusp_poi.nt
#         Mexico/
#           mexico_poi.nt
#         Micronesia/
#           micronesia_poi.nt
#         Moldova/
#           moldova_poi.nt
#         Monaco/
#           monaco_poi.nt
#         Mongolia/
#           mongolia_poi.nt
#         Montenegro/
#           montenegro_poi.nt
#         Mozambique/
#           mozambique_poi.nt
#         Myanmar/
#           myanmar_poi.nt
#         Namibia/
#           namibia_poi.nt
#         Naur/
#           naur_poi.nt
#         Nepal/
#           nepal_poi.nt
#         Netherlands/
#           netherlands_poi.nt
#         New Caledonia/
#           new caledonia_poi.nt
#         New Zealand/
#           new zealand_poi.nt
#         Nicaragua/
#           nicaragua_poi.nt
#         Niger/
#           niger_poi.nt
#         Nigeria/
#           nigeria_poi.nt
#         Niue/
#           niue_poi.nt
#         North Korea/
#           north korea_poi.nt
#         Norway/
#           norway_poi.nt
#         Pakistan/
#           pakistan_poi.nt
#         Palau/
#           palau_poi.nt
#         Panama/
#           panama_poi.nt
#         Papua New Guinea/
#           papua new guinea_poi.nt
#         Paraguay/
#           paraguay_poi.nt
#         Peru/
#           peru_poi.nt
#         Philippines/
#           philippines_poi.nt
#         Pitcairn Islands/
#           pitcairn islands_poi.nt
#         Poland/
#           poland_poi.nt
#         Polynésie francaise/
#           polynésie francaise_poi.nt
#         Portugal/
#           portugal_poi.nt
#         Romania/
#           romania_poi.nt
#         Russia/
#           russia_poi.nt
#         Rwanda/
#           rwanda_poi.nt
#         Saint Helena Ascension and Tristan da Cunha/
#           saint helena ascension and tristan da cunha_poi.nt
#         Samoa/
#           samoa_poi.nt
#         Sao Tome and Principe/
#           sao tome and principe_poi.nt
#         Senegal and Gambia/
#           senegal and gambia_poi.nt
#         Serbia/
#           serbia_poi.nt
#         Seychelles/
#           seychelles_poi.nt
#         Sierra Leone/
#           sierra leone_poi.nt
#         Slovakia/
#           slovakia_poi.nt
#         Slovenia/
#           slovenia_poi.nt
#         Solomon Islands/
#           solomon islands_poi.nt
#         Somalia/
#           somalia_poi.nt
#         South Africa/
#           south africa_poi.nt
#         South Korea/
#           south korea_poi.nt
#         South Sudan/
#           south sudan_poi.nt
#         Spain/
#           spain_poi.nt
#         Sri Lanka/
#           sri lanka_poi.nt
#         Sudan/
#           sudan_poi.nt
#         Suriname/
#           suriname_poi.nt
#         Swaziland/
#           swaziland_poi.nt
#         Sweden/
#           sweden_poi.nt
#         Switzerland/
#           switzerland_poi.nt
#         Syria/
#           syria_poi.nt
#         Taiwan/
#           taiwan_poi.nt
#         Tajikistan/
#           tajikistan_poi.nt
#         Tanzania/
#           tanzania_poi.nt
#         Thailand/
#           thailand_poi.nt
#         Togo/
#           togo_poi.nt
#         Tokelau/
#           tokelau_poi.nt
#         Tonga/
#           tonga_poi.nt
#         Tunisia/
#           tunisia_poi.nt
#         Turkey/
#           turkey_poi.nt
#         Turkmenistan/
#           turkmenistan_poi.nt
#         Tuvalu/
#           tuvalu_poi.nt
#         US/
#           us_poi.nt
#         Uganda/
#           uganda_poi.nt
#         Ukraine/
#           ukraine_poi.nt
#         United Kingdom/
#           united kingdom_poi.nt
#         Uruguay/
#           uruguay_poi.nt
#         Uzbekistan/
#           uzbekistan_poi.nt
#         Vanuatu/
#           vanuatu_poi.nt
#         Venezuela/
#           venezuela_poi.nt
#         Vietnam/
#           vietnam_poi.nt
#         Wallis et Futuna/
#           wallis et futuna_poi.nt
#         Yemen/
#           yemen_poi.nt
#         Zambia/
#           zambia_poi.nt
#         Zimbabwe/
#           zimbabwe_poi.nt
#       waterbodies/
#         Afghanistan/
#           afghanistan_water.nt
#         Albania/
#           albania_water.nt
#         Algeria/
#           algeria_water.nt
#         American Oceania/
#           american oceania_water.nt
#         Andorra/
#           andorra_water.nt
#         Angola/
#           angola_water.nt
#         Antarctica/
#           antarctica_water.nt
#         Argentina/
#           argentina_water.nt
#         Armenia/
#           armenia_water.nt
#         Australia/
#           australia_water.nt
#         Austria/
#           austria_water.nt
#         Azerbaijan/
#           azerbaijan_water.nt
#         Azores/
#           azores_water.nt
#         Bahamas/
#           bahamas_water.nt
#         Bangladesh/
#           bangladesh_water.nt
#         Belarus/
#           belarus_water.nt
#         Belgium/
#           belgium_water.nt
#         Belize/
#           belize_water.nt
#         Benin/
#           benin_water.nt
#         Bhutan/
#           bhutan_water.nt
#         Bolivia/
#           bolivia_water.nt
#         Bosnia-Herzegovina/
#           bosnia-herzegovina_water.nt
#         Botswana/
#           botswana_water.nt
#         Brazil/
#           brazil_water.nt
#         Bulgaria/
#           bulgaria_water.nt
#         Burkina Faso/
#           burkina faso_water.nt
#         Burundi/
#           burundi_water.nt
#         Cambodia/
#           cambodia_water.nt
#         Cameroon/
#           cameroon_water.nt
#         Canada/
#           canada_water.nt
#         Canary Islands/
#           canary islands_water.nt
#         Cape Verde/
#           cape verde_water.nt
#         Central African Republic/
#           central african republic_water.nt
#         Chad/
#           chad_water.nt
#         Chile/
#           chile_water.nt
#         China/
#           china_water.nt
#         Colombia/
#           colombia_water.nt
#         Comores/
#           comores_water.nt
#         Congo Brazzaville/
#           congo brazzaville_water.nt
#         Congo Democratic Republic/
#           congo democratic republic_water.nt
#         Cook Islands/
#           cook islands_water.nt
#         Costa Rica/
#           costa rica_water.nt
#         Croatia/
#           croatia_water.nt
#         Cuba/
#           cuba_water.nt
#         Cyprus/
#           cyprus_water.nt
#         Czech Republic/
#           czech republic_water.nt
#         Denmark/
#           denmark_water.nt
#         Djibouti/
#           djibouti_water.nt
#         East Timor/
#           east timor_water.nt
#         Ecuador/
#           ecuador_water.nt
#         Egypt/
#           egypt_water.nt
#         El Salvador/
#           el salvador_water.nt
#         Equatorial Guinea/
#           equatorial guinea_water.nt
#         Eritrea/
#           eritrea_water.nt
#         Estonia/
#           estonia_water.nt
#         Ethiopia/
#           ethiopia_water.nt
#         Faroe Islands/
#           faroe islands_water.nt
#         Fiji/
#           fiji_water.nt
#         Finland/
#           finland_water.nt
#         France/
#           france_water.nt
#         GCC States/
#           gcc states_water.nt
#         Gabon/
#           gabon_water.nt
#         Georgia/
#           georgia_water.nt
#         Germany/
#           germany_water.nt
#         Ghana/
#           ghana_water.nt
#         Greece/
#           greece_water.nt
#         Greenland/
#           greenland_water.nt
#         Guatemala/
#           guatemala_water.nt
#         Guernsey Jersey/
#           guernsey jersey_water.nt
#         Guinea/
#           guinea_water.nt
#         Guinea-Bissau/
#           guinea-bissau_water.nt
#         Guyana/
#           guyana_water.nt
#         Haiti and Dominican Republic/
#           haiti and dominican republic_water.nt
#         Honduras/
#           honduras_water.nt
#         Hungary/
#           hungary_water.nt
#         Iceland/
#           iceland_water.nt
#         Ile de Clipperton/
#           ile de clipperton_water.nt
#         India/
#           india_water.nt
#         Indonesia/
#           indonesia_water.nt
#         Iran/
#           iran_water.nt
#         Iraq/
#           iraq_water.nt
#         Ireland and Northern Ireland/
#           ireland and northern ireland_water.nt
#         Isle of Man/
#           isle of man_water.nt
#         Israel and Palestine/
#           israel and palestine_water.nt
#         Italy/
#           italy_water.nt
#         Ivory Coast/
#           ivory coast_water.nt
#         Jamaica/
#           jamaica_water.nt
#         Japan/
#           japan_water.nt
#         Jordan/
#           jordan_water.nt
#         Kazakhstan/
#           kazakhstan_water.nt
#         Kenya/
#           kenya_water.nt
#         Kiribati/
#           kiribati_water.nt
#         Kosovo/
#           kosovo_water.nt
#         Kyrgyzstan/
#           kyrgyzstan_water.nt
#         Laos/
#           laos_water.nt
#         Latvia/
#           latvia_water.nt
#         Lebanon/
#           lebanon_water.nt
#         Lesotho/
#           lesotho_water.nt
#         Liberia/
#           liberia_water.nt
#         Libya/
#           libya_water.nt
#         Liechtenstein/
#           liechtenstein_water.nt
#         Lithuania/
#           lithuania_water.nt
#         Luxembourg/
#           luxembourg_water.nt
#         Macedonia/
#           macedonia_water.nt
#         Madagascar/
#           madagascar_water.nt
#         Malawi/
#           malawi_water.nt
#         Malaysia Singapore Brunei/
#           malaysia singapore brunei_water.nt
#         Maldives/
#           maldives_water.nt
#         Mali/
#           mali_water.nt
#         Malta/
#           malta_water.nt
#         Marshall Islands/
#           marshall islands_water.nt
#         Mauritania/
#           mauritania_water.nt
#         Mauritiusp/
#           mauritiusp_water.nt
#         Mexico/
#           mexico_water.nt
#         Micronesia/
#           micronesia_water.nt
#         Moldova/
#           moldova_water.nt
#         Monaco/
#           monaco_water.nt
#         Mongolia/
#           mongolia_water.nt
#         Montenegro/
#           montenegro_water.nt
#         Mozambique/
#           mozambique_water.nt
#         Myanmar/
#           myanmar_water.nt
#         Namibia/
#           namibia_water.nt
#         Naur/
#           naur_water.nt
#         Nepal/
#           nepal_water.nt
#         Netherlands/
#           netherlands_water.nt
#         New Caledonia/
#           new caledonia_water.nt
#         New Zealand/
#           new zealand_water.nt
#         Nicaragua/
#           nicaragua_water.nt
#         Niger/
#           niger_water.nt
#         Nigeria/
#           nigeria_water.nt
#         Niue/
#           niue_water.nt
#         North Korea/
#           north korea_water.nt
#         Norway/
#           norway_water.nt
#         Pakistan/
#           pakistan_water.nt
#         Palau/
#           palau_water.nt
#         Panama/
#           panama_water.nt
#         Papua New Guinea/
#           papua new guinea_water.nt
#         Paraguay/
#           paraguay_water.nt
#         Peru/
#           peru_water.nt
#         Philippines/
#           philippines_water.nt
#         Pitcairn Islands/
#           pitcairn islands_water.nt
#         Poland/
#           poland_water.nt
#         Polynésie francaise/
#           polynésie francaise_water.nt
#         Portugal/
#           portugal_water.nt
#         Romania/
#           romania_water.nt
#         Russia/
#           russia_water.nt
#         Rwanda/
#           rwanda_water.nt
#         Saint Helena Ascension and Tristan da Cunha/
#           saint helena ascension and tristan da cunha_water.nt
#         Samoa/
#           samoa_water.nt
#         Sao Tome and Principe/
#           sao tome and principe_water.nt
#         Senegal and Gambia/
#           senegal and gambia_water.nt
#         Serbia/
#           serbia_water.nt
#         Seychelles/
#           seychelles_water.nt
#         Sierra Leone/
#           sierra leone_water.nt
#         Slovakia/
#           slovakia_water.nt
#         Slovenia/
#           slovenia_water.nt
#         Solomon Islands/
#           solomon islands_water.nt
#         Somalia/
#           somalia_water.nt
#         South Africa/
#           south africa_water.nt
#         South Korea/
#           south korea_water.nt
#         South Sudan/
#           south sudan_water.nt
#         Spain/
#           spain_water.nt
#         Sri Lanka/
#           sri lanka_water.nt
#         Sudan/
#           sudan_water.nt
#         Suriname/
#           suriname_water.nt
#         Swaziland/
#           swaziland_water.nt
#         Sweden/
#           sweden_water.nt
#         Switzerland/
#           switzerland_water.nt
#         Syria/
#           syria_water.nt
#         Taiwan/
#           taiwan_water.nt
#         Tajikistan/
#           tajikistan_water.nt
#         Tanzania/
#           tanzania_water.nt
#         Thailand/
#           thailand_water.nt
#         Togo/
#           togo_water.nt
#         Tokelau/
#           tokelau_water.nt
#         Tonga/
#           tonga_water.nt
#         Tunisia/
#           tunisia_water.nt
#         Turkey/
#           turkey_water.nt
#         Turkmenistan/
#           turkmenistan_water.nt
#         Tuvalu/
#           tuvalu_water.nt
#         US/
#           us_water.nt
#         Uganda/
#           uganda_water.nt
#         Ukraine/
#           ukraine_water.nt
#         United Kingdom/
#           united kingdom_water.nt
#         Uruguay/
#           uruguay_water.nt
#         Uzbekistan/
#           uzbekistan_water.nt
#         Vanuatu/
#           vanuatu_water.nt
#         Venezuela/
#           venezuela_water.nt
#         Vietnam/
#           vietnam_water.nt
#         Wallis et Futuna/
#           wallis et futuna_water.nt
#         Yemen/
#           yemen_water.nt
#         Zambia/
#           zambia_water.nt
#         Zimbabwe/
#           zimbabwe_water.nt

# %% [markdown]
# ### Building your custom GeoKG by selecting from available data sources.

# %%
# Create a KnowledgeGraphBlueprintBuilder object to build the knowledge graph blueprint
builder = KnowledgeGraphBlueprintBuilder()

builder.set_name("ToposKG.nt")
builder.set_output_dir("/content/")

# We add the data sources that we want to include in our GeoKG.
builder.add_source_path("/root/.toposkg/sources_cache/toposkg/GAUL/countries/Greece/Greece_all.nt")
builder.add_source_path("/root/.toposkg/sources_cache/toposkg/OSM/forests/Greece/greece_forest.nt")

# Use the blueprint to construct the knowledge graph
blueprint = builder.build()
blueprint.construct(validate=False) # The required files will be downloaded at this stage if you chose to not download them previously.
                                    # We disable file validation to speed-up the process, and because our files have already been validated.
# Out:
# Constructing knowledge graph...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Knowledge graph constructed successfully at /content/ToposKG.nt
# 'Knowledge graph constructed successfully at /content/ToposKG.nt'

# %%
#
# There are also more powerful ways to add data sources to the builder.
#

# First we clear the previously added data sources.
builder.clear_source_paths()

# We can add data sources via regex.
builder.add_source_paths_with_regex(sources_manager.get_source_paths(), r"(?i).*Greece_(?!\d).*\.nt") # do not include individual level files
print("REGEX")
builder.print_source_paths()

# Or via substring filters
builder.clear_source_paths()
builder.add_source_paths_with_strings(sources_manager.get_source_paths(), ["Greece", "OSM"]) # only include files that contain the strings Greece and OSM in their filepath
print("SUBSTRINGS")
builder.print_source_paths()

# Or even by adding folders, whose contents are considered as the selected data sources.
builder.clear_source_paths()
builder.add_source_path('/root/.toposkg/sources_cache/toposkg/GAUL/countries/Greece')
builder.print_source_paths()
# Out:
# REGEX
# Sources paths:
# - /root/.toposkg/sources_cache/toposkg/GAUL/countries/Greece/Greece_all.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_all.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/forests/Greece/greece_forest.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/pois/Greece/greece_poi.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/waterbodies/Greece/greece_water.nt
# SUBSTRINGS
# Sources paths:
# - /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_0.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_1.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_2.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_3.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_4.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_5.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_6.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_all.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/forests/Greece/greece_forest.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/pois/Greece/greece_poi.nt
# - /root/.toposkg/sources_cache/toposkg/OSM/waterbodies/Greece/greece_water.nt
# Sources paths:
# - /root/.toposkg/sources_cache/toposkg/GAUL/countries/Greece

# %% [markdown]
# ## Advanced Features

# %% [markdown]
# ### Using the translation pipeline to generate English labels.

# %%
builder = KnowledgeGraphBlueprintBuilder()

builder.set_name("ToposKG_translation.nt")
builder.set_output_dir("/content/")

builder.add_source_path("/root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_1.nt")
builder.add_translation_target(("/root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_1.nt", ["<http://toposkg.di.uoa.gr/ontology/hasName>"]))

blueprint = builder.build()
blueprint.construct(debug=True)
# Out:
# Constructing knowledge graph...
# Output()
# Loading source file: /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_1.nt
# Parsing file: /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_1.nt
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Translating...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# ==((====))==  Unsloth 2025.5.7: Fast Gemma3 patching. Transformers: 4.51.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.3.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Using float16 precision for gemma3 won't work! Using float32.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Translating predicates in source path:  /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_1.nt
# Predicates list:  ['<http://toposkg.di.uoa.gr/ontology/hasName>']
# Loading source file: /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_1.nt
# Parsing file: /root/.toposkg/sources_cache/toposkg/OSM/countries/Greece/Greece_1.nt
# Translating "Αποκεντρωμένη Διοίκηση Μακεδονίας - Θράκης" to Region of Macedonia and Thrace Decentralized Administration
# Translating "Makedonias Thrakis" to Thrace
# Translating "Αποκεντρωμένη Διοίκηση Αιγαίου" to Aegean Region Decentralized Administration
# Translating "Kritis" to Crete
# Translating "Ipeiroy Dytikis Makedonias" to West Macedonia
# Translating "Thessaly and Central Greece"@en to Thessaly and Central Greece
# Translating "Macedonia and Thrace"@en to Macedonia and Thrace
# Translating "Αποκεντρωμένη Διοίκηση Ηπείρου - Δυτικής Μακεδονίας" to Region of Epirus-Western Macedonia Decentralized Administration
# Translating "Region of Crete"@en to Crete
# Translating "Thessalias Stereas Elladas" to Thessaly
# Translating "Attikis" to Attica
# Translating "Αποκεντρωμένη Διοίκηση Αττικής" to Attica Region Administrative District
# Translating "Attica"@en to Attica
# Translating "Αποκεντρωμένη Διοίκηση Κρήτης" to Crete Regional Administration
# Translating "Αποκεντρωμένη Διοίκηση Θεσσαλίας - Στερεάς Ελλάδος" to Region of Thessaly and Central Greece
# Translating "Aegean"@en to Aegean Sea
# Translating "Peloponnese, Western Greece and the Ionian"@en to Peloponnese, Western Greece, and the Ionian Islands
# Translating "Αποκεντρωμένη Διοίκηση Πελοποννήσου, Δυτικής Ελλάδας και Ιονίου" to Decentralized Administration of the Peloponnese, Western Greece, and Ionian Islands
# Translating "Peloponnisoy Dytikis Elladas kai Ionioy Nison" to Peloponnese and Ionian Islands
# Translating "Epirus and Western Macedonia"@en to Epirus and Western Macedonia
# Translating "Aigaioy" to Aegean
# Knowledge graph constructed successfully at /content/ToposKG_translation.nt
# 'Knowledge graph constructed successfully at /content/ToposKG_translation.nt'

# %% [markdown]
# ### Using the materialization pipeline.

# %%
# Because the materialization pipeline relies on Java code, and running Java code on Google Colab is not officialy supported we do not include examples for this functionality here.
# You can see examples in the official code repository of toposkg-lib.

# %% [markdown]
# ### Using the entity linking pipeline to link custom data with the official ToposKG data sources.
#
# To extend the available data sources, but also interlink data where appropriate toposkg-lib provides a simple interface to pyjedai. In this example we want to link some custom data to the U.S. States.

# %%
# download data
# !wget https://raw.githubusercontent.com/KwtsPls/ToposKG/refs/heads/main/toposkg_lib/examples/us_states_test_data.csv
# !wget https://raw.githubusercontent.com/KwtsPls/ToposKG/refs/heads/main/toposkg_lib/examples/us_states_gaul.nt
# Out:
# --2025-06-20 17:00:49--  https://raw.githubusercontent.com/KwtsPls/ToposKG/refs/heads/main/toposkg_lib/examples/us_states_test_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1606 (1.6K) [text/plain]
# Saving to: ‘us_states_test_data.csv’
#
# us_states_test_data 100%[===================>]   1.57K  --.-KB/s    in 0s
#
# 2025-06-20 17:00:49 (37.0 MB/s) - ‘us_states_test_data.csv’ saved [1606/1606]
#
# --2025-06-20 17:00:49--  https://raw.githubusercontent.com/KwtsPls/ToposKG/refs/heads/main/toposkg_lib/examples/us_states_gaul.nt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39080053 (37M) [text/plain]
# Saving to: ‘us_states_gaul.nt’
#
# us_states_gaul.nt   100%[===================>]  37.27M   195MB/s    in 0.2s
#
# 2025-06-20 17:00:50 (195 MB/s) - ‘us_states_gaul.nt’ saved [39080053/39080053]

# %%
from toposkg.toposkg_lib_entity_linking import *

# Extract relevant information from the nt file which will be useful for linking with the custom data.
toposkg_nt_to_csv("/content/us_states_gaul.nt", ['http://toposkg.di.uoa.gr/ontology/hasName'], "/content/us_states_gaul.csv")
# Out:
#                                               entity               hasName
# 0   http://toposkg.di.uoa.gr/resource/usa_2353_31486               Wyoming
# 1   http://toposkg.di.uoa.gr/resource/usa_2321_32037                 Maine
# 2   http://toposkg.di.uoa.gr/resource/usa_2333_30844            New Mexico
# 3   http://toposkg.di.uoa.gr/resource/usa_2345_33035                 Texas
# 4   http://toposkg.di.uoa.gr/resource/usa_2341_33325          Rhode Island
# 5   http://toposkg.di.uoa.gr/resource/usa_2317_33332                  Iowa
# 6   http://toposkg.di.uoa.gr/resource/usa_2329_31448              Nebraska
# 7   http://toposkg.di.uoa.gr/resource/usa_2309_31575              Delaware
# 8   http://toposkg.di.uoa.gr/resource/usa_2313_22101                Hawaii
# 9   http://toposkg.di.uoa.gr/resource/usa_2325_33355             Minnesota
# 10  http://toposkg.di.uoa.gr/resource/usa_2337_32879                  Ohio
# 11  http://toposkg.di.uoa.gr/resource/usa_2305_19424              Arkansas
# 12  http://toposkg.di.uoa.gr/resource/usa_2349_32344            Washington
# 13  http://toposkg.di.uoa.gr/resource/usa_2342_32664        South Carolina
# 14  http://toposkg.di.uoa.gr/resource/usa_2310_31072  District Of Columbia
# 15  http://toposkg.di.uoa.gr/resource/usa_2322_32079              Maryland
# 16  http://toposkg.di.uoa.gr/resource/usa_2334_30887              New York
# 17  http://toposkg.di.uoa.gr/resource/usa_2330_33105                Nevada
# 18  http://toposkg.di.uoa.gr/resource/usa_2306_33215            California
# 19  http://toposkg.di.uoa.gr/resource/usa_2318_26263                Kansas
# 20  http://toposkg.di.uoa.gr/resource/usa_2302_31303               Alabama
# 21  http://toposkg.di.uoa.gr/resource/usa_2346_28125                  Utah
# 22  http://toposkg.di.uoa.gr/resource/usa_2314_31615                 Idaho
# 23  http://toposkg.di.uoa.gr/resource/usa_2326_30079           Mississippi
# 24  http://toposkg.di.uoa.gr/resource/usa_2338_33034              Oklahoma
# 25  http://toposkg.di.uoa.gr/resource/usa_2331_32979         New Hampshire
# 26  http://toposkg.di.uoa.gr/resource/usa_2343_33354          South Dakota
# 27  http://toposkg.di.uoa.gr/resource/usa_2311_31784               Florida
# 28  http://toposkg.di.uoa.gr/resource/usa_2323_33321         Massachusetts
# 29  http://toposkg.di.uoa.gr/resource/usa_2351_32078         West Virginia
# 30  http://toposkg.di.uoa.gr/resource/usa_2339_31614                Oregon
# 31  http://toposkg.di.uoa.gr/resource/usa_2307_26270              Colorado
# 32  http://toposkg.di.uoa.gr/resource/usa_2319_32213              Kentucky
# 33  http://toposkg.di.uoa.gr/resource/usa_2335_32665        North Carolina
# 34   http://toposkg.di.uoa.gr/resource/gaul_usa_2303                Alaska
# 35  http://toposkg.di.uoa.gr/resource/usa_2347_32978               Vermont
# 36  http://toposkg.di.uoa.gr/resource/usa_2315_33331              Illinois
# 37  http://toposkg.di.uoa.gr/resource/usa_2327_33045              Missouri
# 38  http://toposkg.di.uoa.gr/resource/usa_2320_30078             Louisiana
# 39  http://toposkg.di.uoa.gr/resource/usa_2332_32833            New Jersey
# 40  http://toposkg.di.uoa.gr/resource/usa_2344_31161             Tennessee
# 41  http://toposkg.di.uoa.gr/resource/usa_2312_31302               Georgia
# 42  http://toposkg.di.uoa.gr/resource/usa_2340_32834          Pennsylvania
# 43  http://toposkg.di.uoa.gr/resource/usa_2352_33061             Wisconsin
# 44  http://toposkg.di.uoa.gr/resource/usa_2328_29645               Montana
# 45  http://toposkg.di.uoa.gr/resource/usa_2308_33311           Connecticut
# 46  http://toposkg.di.uoa.gr/resource/usa_2324_33060              Michigan
# 47  http://toposkg.di.uoa.gr/resource/usa_2336_33246          North Dakota
# 48  http://toposkg.di.uoa.gr/resource/usa_2304_33104               Arizona
# 49  http://toposkg.di.uoa.gr/resource/usa_2348_31994              Virginia
# 50  http://toposkg.di.uoa.gr/resource/usa_2316_32877               Indiana

# %%
# load the two datasets to link them
gaul_df = pd.read_csv("/content/us_states_gaul.csv", sep=',', engine='python', na_filter=False).astype(str)
target_df = pd.read_csv("/content/us_states_test_data.csv", sep=',', engine='python', na_filter=False).astype(str)

# call pyjedai
toposkg_link_dataframes(
    d1=gaul_df,
    id_column_name_1="hasName",
    d2=target_df,
    id_column_name_2="State",
    output_path="/content/link_output_dfs.csv"
)

# converT the pyjedai output to an RDF file, this file and be added to the data sources and included in a custom KG
toposkg_csv_to_nt(
    input_file="/content/link_output_dfs.csv",
    column_id_name="entity",
    output_file="/content/link_output_dfs.nt"
)
# Out:
# Embeddings-NN Block Building [sminilm, faiss, cuda]:   0%|          | 0/101 [00:00<?, ?it/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#                id1             id2
# 0          Alabama         Alabama
# 1           Alaska          Alaska
# 2          Arizona         Arizona
# 3         Arkansas        Arkansas
# 4       California      California
# 5         Colorado        Colorado
# 6      Connecticut     Connecticut
# 7         Delaware        Delaware
# 8          Florida         Florida
# 9          Georgia         Georgia
# 10          Hawaii          Hawaii
# 11           Idaho           Idaho
# 12        Illinois        Illinois
# 13         Indiana         Indiana
# 14            Iowa            Iowa
# 15          Kansas          Kansas
# 16        Kentucky        Kentucky
# 17       Louisiana       Louisiana
# 18           Maine           Maine
# 19        Maryland        Maryland
# 20   Massachusetts   Massachusetts
# 21        Michigan        Michigan
# 22       Minnesota       Minnesota
# 23     Mississippi     Mississippi
# 24        Missouri        Missouri
# 25         Montana         Montana
# 26        Nebraska        Nebraska
# 27          Nevada          Nevada
# 28   New Hampshire   New Hampshire
# 29      New Jersey      New Jersey
# 30      New Mexico      New Mexico
# 31        New York        New York
# 32  North Carolina  North Carolina
# 33    North Dakota    North Dakota
# 34            Ohio            Ohio
# 35        Oklahoma        Oklahoma
# 36          Oregon          Oregon
# 37    Pennsylvania    Pennsylvania
# 38    Rhode Island    Rhode Island
# 39  South Carolina  South Carolina
# 40    South Dakota    South Dakota
# 41       Tennessee       Tennessee
# 42           Texas           Texas
# 43            Utah            Utah
# 44         Vermont         Vermont
# 45        Virginia        Virginia
# 46      Washington      Washington
# 47   West Virginia   West Virginia
# 48       Wisconsin       Wisconsin
# 49         Wyoming         Wyoming
# /usr/local/lib/python3.11/dist-packages/rdflib/plugins/serializers/nt.py:39: UserWarning: NTSerializer always uses UTF-8 encoding. Given encoding was: None
#   warnings.warn(
# <Graph identifier=N0851ef17e7624bc3b48b0b863329a76c (<class 'rdflib.graph.Graph'>)>

# %%
pd.read_csv('/content/link_output_dfs.csv')
# Out:
#                                               entity               hasName  \
# 0   http://toposkg.di.uoa.gr/resource/usa_2353_31486               Wyoming
# 1   http://toposkg.di.uoa.gr/resource/usa_2321_32037                 Maine
# 2   http://toposkg.di.uoa.gr/resource/usa_2333_30844            New Mexico
# 3   http://toposkg.di.uoa.gr/resource/usa_2345_33035                 Texas
# 4   http://toposkg.di.uoa.gr/resource/usa_2341_33325          Rhode Island
# 5   http://toposkg.di.uoa.gr/resource/usa_2317_33332                  Iowa
# 6   http://toposkg.di.uoa.gr/resource/usa_2329_31448              Nebraska
# 7   http://toposkg.di.uoa.gr/resource/usa_2309_31575              Delaware
# 8   http://toposkg.di.uoa.gr/resource/usa_2313_22101                Hawaii
# 9   http://toposkg.di.uoa.gr/resource/usa_2325_33355             Minnesota
# 10  http://toposkg.di.uoa.gr/resource/usa_2337_32879                  Ohio
# 11  http://toposkg.di.uoa.gr/resource/usa_2305_19424              Arkansas
# 12  http://toposkg.di.uoa.gr/resource/usa_2349_32344            Washington
# 13  http://toposkg.di.uoa.gr/resource/usa_2342_32664        South Carolina
# 14  http://toposkg.di.uoa.gr/resource/usa_2310_31072  District Of Columbia
# 15  http://toposkg.di.uoa.gr/resource/usa_2322_32079              Maryland
# 16  http://toposkg.di.uoa.gr/resource/usa_2334_30887              New York
# 17  http://toposkg.di.uoa.gr/resource/usa_2330_33105                Nevada
# 18  http://toposkg.di.uoa.gr/resource/usa_2306_33215            California
# 19  http://toposkg.di.uoa.gr/resource/usa_2318_26263                Kansas
# 20  http://toposkg.di.uoa.gr/resource/usa_2302_31303               Alabama
# 21  http://toposkg.di.uoa.gr/resource/usa_2346_28125                  Utah
# 22  http://toposkg.di.uoa.gr/resource/usa_2314_31615                 Idaho
# 23  http://toposkg.di.uoa.gr/resource/usa_2326_30079           Mississippi
# 24  http://toposkg.di.uoa.gr/resource/usa_2338_33034              Oklahoma
# 25  http://toposkg.di.uoa.gr/resource/usa_2331_32979         New Hampshire
# 26  http://toposkg.di.uoa.gr/resource/usa_2343_33354          South Dakota
# 27  http://toposkg.di.uoa.gr/resource/usa_2311_31784               Florida
# 28  http://toposkg.di.uoa.gr/resource/usa_2323_33321         Massachusetts
# 29  http://toposkg.di.uoa.gr/resource/usa_2351_32078         West Virginia
# 30  http://toposkg.di.uoa.gr/resource/usa_2339_31614                Oregon
# 31  http://toposkg.di.uoa.gr/resource/usa_2307_26270              Colorado
# 32  http://toposkg.di.uoa.gr/resource/usa_2319_32213              Kentucky
# 33  http://toposkg.di.uoa.gr/resource/usa_2335_32665        North Carolina
# 34   http://toposkg.di.uoa.gr/resource/gaul_usa_2303                Alaska
# 35  http://toposkg.di.uoa.gr/resource/usa_2347_32978               Vermont
# 36  http://toposkg.di.uoa.gr/resource/usa_2315_33331              Illinois
# 37  http://toposkg.di.uoa.gr/resource/usa_2327_33045              Missouri
# 38  http://toposkg.di.uoa.gr/resource/usa_2320_30078             Louisiana
# 39  http://toposkg.di.uoa.gr/resource/usa_2332_32833            New Jersey
# 40  http://toposkg.di.uoa.gr/resource/usa_2344_31161             Tennessee
# 41  http://toposkg.di.uoa.gr/resource/usa_2312_31302               Georgia
# 42  http://toposkg.di.uoa.gr/resource/usa_2340_32834          Pennsylvania
# 43  http://toposkg.di.uoa.gr/resource/usa_2352_33061             Wisconsin
# 44  http://toposkg.di.uoa.gr/resource/usa_2328_29645               Montana
# 45  http://toposkg.di.uoa.gr/resource/usa_2308_33311           Connecticut
# 46  http://toposkg.di.uoa.gr/resource/usa_2324_33060              Michigan
# 47  http://toposkg.di.uoa.gr/resource/usa_2336_33246          North Dakota
# 48  http://toposkg.di.uoa.gr/resource/usa_2304_33104               Arizona
# 49  http://toposkg.di.uoa.gr/resource/usa_2348_31994              Virginia
# 50  http://toposkg.di.uoa.gr/resource/usa_2316_32877               Indiana
#
#              State  test_data_1  test_data_2
# 0          Wyoming        957.0    82.105510
# 1            Maine        529.0    75.330291
# 2       New Mexico        157.0    27.509986
# 3            Texas        385.0    94.979713
# 4     Rhode Island        562.0     6.918714
# 5             Iowa        639.0     9.904071
# 6         Nebraska        304.0    64.854264
# 7         Delaware        605.0    13.283306
# 8           Hawaii        726.0    51.758871
# 9        Minnesota        149.0    70.958202
# 10            Ohio        618.0    67.766254
# 11        Arkansas        690.0    93.146184
# 12      Washington        599.0    99.742512
# 13  South Carolina        213.0    45.893249
# 14             NaN          NaN          NaN
# 15        Maryland         32.0    45.936427
# 16        New York        195.0    75.687014
# 17          Nevada        517.0    93.528191
# 18      California        304.0    13.647139
# 19          Kansas        927.0     1.653087
# 20         Alabama        510.0    88.990821
# 21            Utah        151.0    44.875207
# 22           Idaho        207.0    24.994472
# 23     Mississippi        899.0    81.054715
# 24        Oklahoma        916.0    32.359520
# 25   New Hampshire        802.0    62.940535
# 26    South Dakota        531.0    15.430662
# 27         Florida        444.0    35.281212
# 28   Massachusetts        251.0    92.008084
# 29   West Virginia        746.0    67.545204
# 30          Oregon        943.0    36.130091
# 31        Colorado        687.0    85.343230
# 32        Kentucky        462.0    73.593475
# 33  North Carolina        504.0    51.006873
# 34          Alaska        347.0     1.250070
# 35         Vermont        740.0    46.601790
# 36        Illinois        721.0    60.353995
# 37        Missouri        383.0    11.959339
# 38       Louisiana        657.0    90.934181
# 39      New Jersey        665.0    93.069620
# 40       Tennessee        196.0    40.412183
# 41         Georgia        815.0    74.443440
# 42    Pennsylvania        846.0     9.661891
# 43       Wisconsin        675.0    75.297476
# 44         Montana        367.0    19.826938
# 45     Connecticut        177.0    33.825916
# 46        Michigan        737.0    97.350535
# 47    North Dakota        370.0    16.153904
# 48         Arizona        774.0    80.280673
# 49        Virginia        408.0    44.413559
# 50         Indiana        932.0    38.159819
